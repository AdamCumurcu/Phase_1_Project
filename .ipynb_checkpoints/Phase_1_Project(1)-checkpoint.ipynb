# %% [markdown]
# # Getting Your Data From Yelp!

# %% [markdown]
# In order to make sure you are on track to completing the project, you will complete this workbook first. Below are steps that you need to take in order to make sure you have your data from yelp and are ready to analyze it. Your cohort lead will review this workbook with you the Wednesday before your project is due.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# You will be pulling data from the Yelp API to complete your analysis. The api, however, provides you with a lot of information that will not be pertinent to your analysis. YOu will pull data from the api and parse through it to keep only the data that you will need. In order to help you identify that information,look at the API documentation and understand what data the api will provide you.
#
# Identify which data fields you will want to keep for your analysis.
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ___

# %% [markdown]
# ## Part 2 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %% [markdown]
# - Write a function to make a call to the yelp API

# %%
import pandas as pd
import requests
import json

# %%
with open('C:/Users/acumu/Documents/Flatiron/ds-east-042621-lectures/Phase_1/ds-apis-nbz32-main/.secrets/creds.json') as f:
    creds = json.load(f)

# %%
api_key = creds['key']
term = 'bicycle'
location = 'Washington DC'
SEARCH_LIMIT = 50
url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'offset': 0 
    }

# %%
def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer ' + api_key}
    
    data = requests.get(url, headers = headers, params = url_params)
    return data

# %%
results = yelp_call(url_params, api_key)

# %%
results.json()['businesses']
# Out:
# [{'id': 'Dn04j5YabUDWS7nUbpfZGg',
#   'alias': 'the-daily-rider-washington-2',
#   'name': 'The Daily Rider',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jRfGdCPbaWmgXfRGc7FZWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-daily-rider-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#   'review_count': 85,
#   'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#    {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.9004, 'longitude': -76.99815},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '600 H St NE',
#    'address2': 'Ste D',
#    'address3': '',
#    'city': 'Washington, DC',
#    'zip_code': '20002',
#    'country': 'US',
#    'state': 'DC',
#    'display_address': ['600 H St NE', 'Ste D', 'Washington, DC 20002']},
# ...

# %%
#def get_aliases(cell):
#    alias = []
#    for alii in cell:
#        alias.append(allii['alias'])
#    return alias

# %%
#df['parsed_alias'] = df['alias'].apply(get_aliases)

# %% [markdown]
# - Write a function to parse the API response so that you can easily insert the data in to the DB

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    results = results.json()['businesses']
    parsed_data = []
    for business in results:
        if 'price' not in business:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], 'NaN', business['location']['address1'], 
                business['location']['city'], business['location']['state'],
                business['location']['zip_code'], business['coordinates']['latitude'], business['coordinates']['longitude'])
            parsed_data.append(biz_info)
        else:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], business['price'], business['location']['address1'], 
                business['location']['city'], business['location']['state'],
                business['location']['zip_code'], business['coordinates']['latitude'], business['coordinates']['longitude'])
            parsed_data.append(biz_info)
    return parsed_data

# %%
biker_df = pd.DataFrame(parse_results(results), columns = ('ID', 'Name', 'Is_Closed',
                                           'Review_Count', 'Rating', 'Price', 'Address', 'City', 'State',
                                           'Zip_Code', 'Latitude', 'Longitude'))

# %%
#biker_df

# %%
#def get_aliases(cell):
#    alias = []
#    for alii in cell:
#        alias.append(allii['alias'])
#    return alias

# %%
#biker_df['parsed_alias'] = biker_df['alias'].apply(get_aliases)

# %%
#biker_df.to_csv('washington_data.csv', index_col = 0)

# %% [markdown]
# - Write a function to take your parsed data and add it to the csv file where you will store all of your results.

# %%
#biker_df.to_csv('C:/Users/acumu/Documents/Flatiron/Phase_1_Project/bikedata.csv', mode='a', index=False, header=False)

# %%
parsed_results = parse_results(results)

# %%
def df_safe(csv_filepath, parsed_results):
    # your code to open the csv file, concat the current data, and save the data. 
    parsed_results = pd.DataFrame(parsed_results)
    return parsed_results.to_csv(csv_filepath, mode = 'a', index = False, header = False)

# %%
csv_filepath = 'C:/Users/acumu/Documents/Flatiron/Phase_1_Project/washington_data.csv'
#t_ = df_safe(csv_filepath, parsed_results)

# %% [markdown]
# - Write a script that combines the three functions above into a single process.

# %% [markdown]
# While it will take some experimentation to write the functions above, once you get them working it will be best to put them in a `.py` file and then import the functions to use in a script

# %%
#from helper_funcs import *

# %%
pd.DataFrame(columns = ('ID', 'Name', 'Is_Closed', 'Review_Count', 'Rating', 'Price', 
                        'Address1', 'City', 'State', 'Zip_Code', 'Latitude', 'Longitude'))\
                        .to_csv('washington_data.csv', index = False)

# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < 1000 and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    df_safe(csv_filepath, parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50

# %%
pd.set_option('display.max_rows', None)
bike_df = pd.read_csv('washington_data.csv')
bike_df
# Out:
#                         ID                                     Name  \
# 0   Dn04j5YabUDWS7nUbpfZGg                          The Daily Rider
# 1   yGJ5jSQPSqp8i5rojSJnHQ                      Gearin' Up Bicycles
# 2   ATpgglOwwQUno5QhAEXc2g                            Bicycle Space
# 3   2q9eO68Q-PDAUUfdx-zvqw                           The Bike House
# 4   3tbIAR6xTrgSRO3m2da0Vg                        Conte's Bike Shop
# 5   dEUQ7Of8leYhaRF12qTswQ                           Takoma Bicycle
# 6   F0fMNrrBU3OKMdwfCL5mRA                         Upshift Workshop
# 7   obfGllLjyMkQ1iA_HtT1bQ                   Eric's Mobile Workshop
# 8   8mwlRyZ6FH2VW10tlHE2Qg                         Bicycle Pro Shop
# 9   Wqmx9LXrKzAUGeTZRV3XZg                    City Bikes Tenleytown
# 10  R2HBjZ0HYWIRquHMVBNA_w  Trek Bicycle Washington D.C. Georgetown
# 11  8eVGxeIopFn5hUX_YVkbGQ                       Nomad Bicycleworks
# 12  cU4Dg9ltf53aFoLBh8Ndkw                            Silver Cycles
# ...

# %%
#bike_df = bike_df.drop([54, 73, 77])

# %%
#bike_df

# %%
#def df_save(parsed_results, csv_name):
#    
#        #write the header if the file doesn't exist already
#    if not os.path.isfile(csv_name):
#        parsed_results.to_csv(csv_name, header='column_names', index = False)
#    else: # else it exists so append without writing the header
#        parsed_results.to_csv(csv_name, mode='a', header=False, index = False)

# %% [markdown]
# ___

# %% [markdown]
# ## Part 3 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews. Above you ahve a model of the functions you will need to write, and how to pull them together in one script. For this part, you ahve the process below

# %% [markdown]
# - In order to pull the reveiws, you will need the business ids. So your first step will be to get all of the business ids from your businesses csv.

# %% [markdown]
# - Write a function that takes a business id and makes a call to the API for reivews

# %%
business_ids = pd.read_csv('washington_data.csv')
business_ids
# Out:
#                         ID                                     Name  \
# 0   Dn04j5YabUDWS7nUbpfZGg                          The Daily Rider
# 1   yGJ5jSQPSqp8i5rojSJnHQ                      Gearin' Up Bicycles
# 2   ATpgglOwwQUno5QhAEXc2g                            Bicycle Space
# 3   2q9eO68Q-PDAUUfdx-zvqw                           The Bike House
# 4   3tbIAR6xTrgSRO3m2da0Vg                        Conte's Bike Shop
# 5   dEUQ7Of8leYhaRF12qTswQ                           Takoma Bicycle
# 6   F0fMNrrBU3OKMdwfCL5mRA                         Upshift Workshop
# 7   obfGllLjyMkQ1iA_HtT1bQ                   Eric's Mobile Workshop
# 8   8mwlRyZ6FH2VW10tlHE2Qg                         Bicycle Pro Shop
# 9   Wqmx9LXrKzAUGeTZRV3XZg                    City Bikes Tenleytown
# 10  R2HBjZ0HYWIRquHMVBNA_w  Trek Bicycle Washington D.C. Georgetown
# 11  8eVGxeIopFn5hUX_YVkbGQ                       Nomad Bicycleworks
# 12  cU4Dg9ltf53aFoLBh8Ndkw                            Silver Cycles
# ...

# %%
def yelp_call_review(business_id, creds):
    review_api_key = creds['key']
    url = 'https://api.yelp.com/v3/businesses/'+ str(business_id) +'/reviews'
    headers = {'Authorization': 'Bearer ' + api_key}
    data = requests.get(url, headers = headers)    
    return data.json()['reviews']

# %% [markdown]
# - Write a function to parse out the relevant information from the reviews

# %%
def parse_results_review(results, business):
    # your code to parse the result to make them easier to insert into the DB
    parsed_data = []
    for review in results:
        biz_info = (business, review['id'], review['text'], review['rating'], review['time_created'],
                   review['user']['name'])
        parsed_data.append(biz_info)
    return parsed_data

# %% [markdown]
# - Write a function to save the parse data into a csv file containing all of the reviews.

# %%
def df_safe_review(csv_review_filepath, parsed_results):
    # your code to open the csv file, concat the current data, and save the data. 
    parsed_results = pd.DataFrame(parsed_results)
    return parsed_results.to_csv(csv_review_filepath, mode = 'a', index = False, header = False)

# %% [markdown]
# - Combine the functions above into a single script

# %%
dc_business_df = pd.read_csv('washington_data.csv')

# %%
pd.DataFrame(columns = ('Business_ID', 'Review_ID', 'Text', 'Review_Rating', 'Time_Created', 'User_Name'))\
                        .to_csv('washington_data_review.csv', index = False)
# create a variable  to keep track of which result you are in. 
for business in dc_business_df['ID']:

    results = yelp_call_review(business, creds)    

    parsed_results = parse_results_review(results, business)    

    df_safe_review('washington_data_review.csv', parsed_results)

# %% [markdown]
# ## Part 4 -  Using python and pandas, write code to answer the questions below.

# %%
#Create panda dataframes for NY data
ny_business_df = pd.read_csv('new_york_bike_data.csv')
ny_business_reviews_df = pd.read_csv('new_york_bike_data_review.csv')

# %%
#Replace price data ($) with number values
ny_business_df['Price'] = ny_business_df[ny_business_df['Price'].isna() == False]['Price'].map(lambda x: len(x))

# %%
#Create panda dataframes for DC data
#dc_business_df = pd.read_csv('washington_data.csv')
dc_business_reviews_df = pd.read_csv('washington_data_review.csv')

# %%
#Replace price data ($) with number values
dc_business_df['Price'] = dc_business_df[dc_business_df['Price'].isna() == False]['Price'].map(lambda x: len(x))

# %%
dc_business_df
# Out:
#                         ID                                     Name  \
# 0   Dn04j5YabUDWS7nUbpfZGg                          The Daily Rider
# 1   yGJ5jSQPSqp8i5rojSJnHQ                      Gearin' Up Bicycles
# 2   ATpgglOwwQUno5QhAEXc2g                            Bicycle Space
# 3   2q9eO68Q-PDAUUfdx-zvqw                           The Bike House
# 4   3tbIAR6xTrgSRO3m2da0Vg                        Conte's Bike Shop
# 5   dEUQ7Of8leYhaRF12qTswQ                           Takoma Bicycle
# 6   F0fMNrrBU3OKMdwfCL5mRA                         Upshift Workshop
# 7   obfGllLjyMkQ1iA_HtT1bQ                   Eric's Mobile Workshop
# 8   8mwlRyZ6FH2VW10tlHE2Qg                         Bicycle Pro Shop
# 9   Wqmx9LXrKzAUGeTZRV3XZg                    City Bikes Tenleytown
# 10  R2HBjZ0HYWIRquHMVBNA_w  Trek Bicycle Washington D.C. Georgetown
# 11  8eVGxeIopFn5hUX_YVkbGQ                       Nomad Bicycleworks
# 12  cU4Dg9ltf53aFoLBh8Ndkw                            Silver Cycles
# ...

# %%
most_reviewed = dc_business_df.sort_values(by = ['Review_Count'], ascending = False)
most_reviewed[:5]
# Out:
#                         ID                              Name  Is_Closed  \
# 75  Flml5W1-uOi79B-PFVBcrw                 Capital Bikeshare      False
# 28  MnV2zaZSXToe-vpkTccZ4Q                  Bike And Roll DC      False
# 20  YvDCWE1O_Q6JLMiKHb4tGQ         City Bikes - Adams Morgan      False
# 47  CmJmSF3Cw0lxuxwusJV8_Q  Trek Bicycle Arlington Clarendon      False
# 39  Nnfhnuqv2WTeHRs_mDFPRA                   Big Wheel Bikes      False
#
#     Review_Count  Rating  Price              Address1            City State  \
# 75           385     2.5    NaN                   NaN  Washington, DC    DC
# 28           328     4.5    NaN   955 L'Enfant Plz SW  Washington, DC    DC
# 20           257     3.0    3.0  2501 Champlain St NW  Washington, DC    DC
# 47           171     3.5    3.0      2731 Wilson Blvd       Arlington    VA
# 39           165     4.5    2.0           2 Prince St      Alexandria    VA
#
#     Zip_Code   Latitude  Longitude
# 75     20010  38.931904 -77.033058
# ...

# %%
# 1. The 5 most reviewed business are Capital Bikeshare (385), Bike and Roll DC (328),
#    City Bikes-Adams Morgan (257), Trek Bicycle Arlington Clarendon (171),
#    Big Wheel Bikes (165)

# %%
pd.set_option('display.max_rows', None)
dc_business_df.sort_values(by = ['Rating'], ascending = False)
# Out:
#                         ID                                     Name  \
# 41  1q-0mrzsr1EIF5U0aTPFXQ                               ProBike FC
# 32  wsqXGUVytcMziH31LRm0mw                   Electric Cycling House
# 76  iFxPRQShEUJ2gKcpWFar8g                Hybrid Pedals - Baltimore
# 74  oX7GdWlqbXEaWv3C8zRxQw          Pedego Electric Bikes Frederick
# 71  9O8jiDSt_0pJYCd-DoN4Xg                       Everything Esmonde
# 65  jfeTiX1IqUSI1wAxSVkjXg                           Veni Vidi Velo
# 62  F4fPzyVvH4Yk4hr-q3SUtw                                #1 Ebikes
# 55  AjIOtN_0SlyY2dgVuBbwhg                             Jafe Cycling
# 52  CMUiknULM7ihWKWK8LbTAg                        Bike Club Bicycle
# 50  OxnwyBMJN43a_5UHL3UHWQ                                  velofix
# 46  rLBUUBSBArIy9hxJncaRUg                            Hybrid Pedals
# 43  YvguUf5tL6HDElwIAhjZ4Q                     Wheel Nuts Bike Shop
# 42  uq9j3G6MJtd_Mv5rfF5oRQ         Pedego Electric Bikes Alexandria
# ...

# %%
len(dc_business_df[dc_business_df["Rating"] ==5])
# Out:
# 22

# %%
#2. The highest rating is 5 and 22 businesses received this rating

# %%
(len(dc_business_df[dc_business_df['Rating'] >= 4.5])/len(business_df)) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-b1d49f0b89a1> in <module>
# ----> 1 (len(dc_business_df[dc_business_df['Rating'] >= 4.5])/len(business_df)) * 100
#
# NameError: name 'business_df' is not defined

# %%
#3 The percentage of business that have a rating greater than or equal to 4.5 is 53.6%

# %%
(len(dc_business_df[dc_business_df['Rating'] < 3])/len(dc_business_df)) * 100
# Out:
# 4.878048780487805

# %%
#4 The percentage of businesses that have a rating  less than 3 is 4.9%

# %%
(len(dc_business_df[dc_business_df['Price'] == 1])/len(dc_business_df)) * 100
# Out:
# 6.097560975609756

# %%
(len(dc_business_df[dc_business_df['Price'] == 2])/len(dc_business_df)) * 100
# Out:
# 45.1219512195122

# %%
(len(dc_business_df[dc_business_df['Price'] == 3])/len(dc_business_df)) * 100
# Out:
# 8.536585365853659

# %%
(len(dc_business_df[dc_business_df['Price'] == 0])/len(dc_business_df)) * 100
# Out:
# 0.0

# %%
#5 The percentage of businesses that have a price label of one dollar sign is 6.1%
#  The percentage of businesses that have a price label of two dollars signs is 45.1%
#  The percentage of businesses that have a price label of three dollars signs is 8.5%
#  The percentage of businesses that have a price label of zero is zero

# %%
dc_business_reviews_df
# Out:
#                 Business_ID               Review_ID  \
# 0    Dn04j5YabUDWS7nUbpfZGg  A0dyOENY1NRjJG7NwALKNQ
# 1    Dn04j5YabUDWS7nUbpfZGg  stRgQAb4X-oACKdrlHiXNw
# 2    Dn04j5YabUDWS7nUbpfZGg  M3_-ncXEuJTR3FsjHWexkw
# 3    yGJ5jSQPSqp8i5rojSJnHQ  iYmvxaTg8dvDm1XNnt7GCw
# 4    yGJ5jSQPSqp8i5rojSJnHQ  u7ReWbbVl1oFl0mNWBcngg
# 5    yGJ5jSQPSqp8i5rojSJnHQ  3LKpnci7JGUl209WXhjtiQ
# 6    ATpgglOwwQUno5QhAEXc2g  k6qaZxTuu2fzw_GMn3X3oQ
# 7    ATpgglOwwQUno5QhAEXc2g  Vb7KeUt4PaK0hWPaIUKuwQ
# 8    ATpgglOwwQUno5QhAEXc2g  2J0_vCUztkDsxP29BN8bRg
# 9    2q9eO68Q-PDAUUfdx-zvqw  bAe13H8laEJoCVOTZZnUeg
# 10   2q9eO68Q-PDAUUfdx-zvqw  rk8dmMdFxiUozoCqxlb0nQ
# 11   2q9eO68Q-PDAUUfdx-zvqw  ieDjgCxvM6aewS8QrCbpmQ
# 12   3tbIAR6xTrgSRO3m2da0Vg  _s3wuExOmy_m5izsOFW8EQ
# 13   3tbIAR6xTrgSRO3m2da0Vg  sg_4YsJb3xagnM1sHBkwGA
# 14   3tbIAR6xTrgSRO3m2da0Vg  rknQVnR5UnjjotNvTfhcXQ
# 15   dEUQ7Of8leYhaRF12qTswQ  mXaZaakKxQE0G3NtXzbiYw
# 16   dEUQ7Of8leYhaRF12qTswQ  lQCoCuextvJVYJ4d4fcY_w
# ...

# %%
len(dc_business_reviews_df)
# Out:
# 234

# %%
pd.set_option('display.max_rows', None)
dc_business_reviews_df.sort_values(by = ['Business_ID'], ascending = False)
# Out:
#                 Business_ID               Review_ID  \
# 139  z9Enbz9rh9Ku91dN7TDJJw  9WxuGEgcwI3DIflcdZpmIg
# 141  z9Enbz9rh9Ku91dN7TDJJw  lKjam9v9fv3sKUoA2bVQpQ
# 140  z9Enbz9rh9Ku91dN7TDJJw  f6EgbY8QrkMo-2r_GuU_Fg
# 3    yGJ5jSQPSqp8i5rojSJnHQ  iYmvxaTg8dvDm1XNnt7GCw
# 4    yGJ5jSQPSqp8i5rojSJnHQ  u7ReWbbVl1oFl0mNWBcngg
# 5    yGJ5jSQPSqp8i5rojSJnHQ  3LKpnci7JGUl209WXhjtiQ
# 190  xplJcyRK765GeB2-22qL-g  Gla4egDLN50FZvg8kEHQpQ
# 192  xplJcyRK765GeB2-22qL-g  f7ehIBpxh6_ynnVhwpMr4g
# 191  xplJcyRK765GeB2-22qL-g  n_sKmabUZBp14t2FPzlxNg
# 90   xTrJ9Q5tNAAkj5p9Du7yRw  sIFGgRotI_cVS6JU16j86A
# 91   xTrJ9Q5tNAAkj5p9Du7yRw  CU31dOfifXDsoCEWQ5H1ag
# 92   xTrJ9Q5tNAAkj5p9Du7yRw  _3eM4HdS0TR5RdASc4kbeQ
# 106  xSzKaAq6vgZZDn3S5-V9Hw  AoZ6DxQJFiCGTdMvlS-HTA
# 104  xSzKaAq6vgZZDn3S5-V9Hw  kqj6c2Jxzg2Dp5J_H_lXFA
# 105  xSzKaAq6vgZZDn3S5-V9Hw  qyIVBI-4iZTdrVGSw9q1rQ
# 75   wuFuQt1lI0kvy8ZaCie8WQ  nrgwQgawhdLSojsv6ZJmrA
# 76   wuFuQt1lI0kvy8ZaCie8WQ  Og2pj6vrgy2h7hRpaCI5rw
# ...

# %%
#most_reviewed[:3]['ID']

# %%
most_reviews_text = []
for i in range(len(dc_business_reviews_df)):
    if most_reviewed.values[0][0] in dc_business_reviews_df.iloc[i]['Business_ID']:
        most_reviews_text.append(dc_business_reviews_df['Text'][i])
print(most_reviews_text)
# Out:
# ['I use Capital Bikeshare regularly for transportation purposes. For the most part, I do not use Capital Bikeshare for pure leisure or tourism. Particularly...', 'I thought this was a great way to get around the city for the price. It took a little bit to get used to the app and find out where bikes were and if they...', 'Do yourself a favor and walk or ride a public bus. The directions for use is shoddy. The first kiosk we started at had plenty of bikes, but over half of...']

# %%
# 6 Capital Bikeshare
# 'I use Capital Bikeshare regularly for transportation purposes. 
#For the most part, I do not use Capital Bikeshare for pure leisure or tourism. Particularly...', 
#'I thought this was a great way to get around the city for the price. 
#It took a little bit to get used to the app and find out where bikes were and if they...', 
#'Do yourself a favor and walk or ride a public bus. The directions for use is shoddy. 
#The first kiosk we started at had plenty of bikes, but over half of...'

# %%
dc_business_reviews_df['Time_Created'] = pd.to_datetime(dc_business_reviews_df['Time_Created'])

# %%
five_star_most_reviews = most_reviewed[most_reviewed['Rating'] == 5][:1]
five_star_most_reviews


dc_business_reviews_df[dc_business_reviews_df['Business_ID'] == five_star_most_reviews.values[0][0]]\
.sort_values(by = ['Time_Created'], ascending = False).head(1)['Text'].values[0]
# Out:
# 'went here after seeing positive reviews and was not disappointed. brought my bike in for shifter adjustment and bottom crank removal. on two separate...'

# %%
five_star_most_reviews.values[0][0]
# Out:
# 'YvguUf5tL6HDElwIAhjZ4Q'

# %%
# 7 Wheel-Nuts-Bike
# went here after seeing positive reviews and was not disappointed. 
#brought my bike in for shifter adjustment and bottom crank removal. on two separate...

# %%
least_reviewed = dc_business_df.sort_values(by = ['Rating'], ascending = True)
least_reviewed[:5]
# Out:
#                         ID                   Name  Is_Closed  Review_Count  \
# 79  4KByEapBENUAhNxW0xJFQA    Bikes For the World      False             1
# 63  Z8r2tI98-fNTREXPIjbNRw        Big Wheel Bikes      False            20
# 78  Cdyo7Hk8P-bn_7b4sRcqUQ  DICK'S Sporting Goods      False            99
# 75  Flml5W1-uOi79B-PFVBcrw      Capital Bikeshare      False           385
# 80  pSXe36HAlL5V9XgJv0o3xw  DICK'S Sporting Goods      False            41
#
#     Rating  Price               Address1                 City State  Zip_Code  \
# 79     1.0    NaN         3108 17th St N            Arlington    VA     22201
# 63     2.5    NaN          9931 Falls Rd              Potomac    MD     20854
# 78     2.5    2.0     5716 Columbia Pike  Bailey's Crossroads    VA     22041
# 75     2.5    NaN                    NaN       Washington, DC    DC     20010
# 80     3.0    2.0  6601 Springfield Mall          Springfield    VA     22150
#
#      Latitude  Longitude
# ...

# %%
one_star_least_reviews = least_reviewed[least_reviewed['Rating'] == 1][:1]

# %%
dc_business_reviews_df[dc_business_reviews_df['Business_ID'] == one_star_least_reviews.values[0][0]]\
.sort_values(by = ['Time_Created'], ascending = False).head(1)['Text'].values[0]
# Out:
# 'I called to donate a bicycle in excellent condition.  I was referred to another individual.  We spoke by phone.  I gave him my address and we arranged a...'

# %%
one_star_least_reviews.values[0][0]
# Out:
# '4KByEapBENUAhNxW0xJFQA'

# %%
# 8 Bikes For the World
# I called to donate a bicycle in excellent condition.  I was referred to another individual.  We spoke by phone.  
# I gave him my address and we arranged a...

# %% [markdown]
# - Which are the 5 most reviewed businesses in your dataset?

# %% [markdown]
# - What is the highest rating recieved in your data set and how many businesses have that rating?

# %% [markdown]
# - What percentage of businesses have a rating greater than or  4.5?

# %% [markdown]
# - What percentage of businesses have a rating less than 3?

# %% [markdown]
# - What percentage of your businesseshave a price label of one dollar sign? Two dollar signs? Three dollar signs? No dollar signs?

# %% [markdown]
# - Return the text of the reviews for the most reviewed business.

# %% [markdown]
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the business with the most reviews.

# %% [markdown]
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the business with the least reviews.

# %%
# 1. The 5 most reviewed business are Capital Bikeshare (385), Bike and Roll DC (328),
#    City Bikes-Adams Morgan (257), Trek Bicycle Arlington Clarendon (171),
#    Big Wheel Bikes (165)

# %%
# 2. The highest rating is 5 and 22 businesses received this rating

# %%
# 3. The percentage of business that have a rating greater than or equal to 4.5 is 53.6%

# %%
# 4. The percentage of businesses that have a rating  less than 3 is 4.9%

# %%
# 5. The percentage of businesses that have a price label of one dollar sign is 6.1%
#  The percentage of businesses that have a price label of two dollars signs is 45.1%
#  The percentage of businesses that have a price label of three dollars signs is 8.5%
#  The percentage of businesses that have a price label of zero is zero

# %%
# 6. Capital Bikeshare
#    -'I use Capital Bikeshare regularly for transportation purposes. 
#      For the most part, I do not use Capital Bikeshare for pure leisure or tourism. Particularly...', 
#    -'I thought this was a great way to get around the city for the price. 
#      It took a little bit to get used to the app and find out where bikes were and if they...', 
#    -'Do yourself a favor and walk or ride a public bus. The directions for use is shoddy. 
#      The first kiosk we started at had plenty of bikes, but over half of...'

# %%
# 7. Wheel-Nuts-Bike
#   -'went here after seeing positive reviews and was not disappointed. 
#     brought my bike in for shifter adjustment and bottom crank removal. on two separate...'

# %%
# 8. Bikes For the World
#  -'I called to donate a bicycle in excellent condition.  I was referred to another individual.  We spoke by phone.  
#    I gave him my address and we arranged a...

# %% [markdown]
# # Visualization 1 (addressing Question 2)
# # Use a bar chart to show percentage of businesses in each city which received ratings 1-5

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import numpy as np

# %%
dc_rating_df = dc_business_df.value_counts('Rating').to_frame()
dc_rating_df.columns = ['Num of Businesses']
dc_rating_df
# Out:
#         Num of Businesses
# Rating
# 5.0                    22
# 4.5                    22
# 4.0                    13
# 3.5                    12
# 3.0                     9
# 2.5                     3
# 1.0                     1

# %%
dc_rating_df['Ratings'] = dc_rating_df.index
dc_rating_df
# Out:
#         Num of Businesses  Ratings
# Rating
# 5.0                    22      5.0
# 4.5                    22      4.5
# 4.0                    13      4.0
# 3.5                    12      3.5
# 3.0                     9      3.0
# 2.5                     3      2.5
# 1.0                     1      1.0

# %%
dc_rating_df['Num of Businesses'].sum()
# Out:
# 82

# %%
dc_rating_df['percentages'] = (dc_rating_df['Num of Businesses']/dc_rating_df['Num of Businesses'].sum()) * 100
dc_rating_df
# Out:
#         Num of Businesses  Ratings  percentages
# Rating
# 5.0                    22      5.0    26.829268
# 4.5                    22      4.5    26.829268
# 4.0                    13      4.0    15.853659
# 3.5                    12      3.5    14.634146
# 3.0                     9      3.0    10.975610
# 2.5                     3      2.5     3.658537
# 1.0                     1      1.0     1.219512

# %%
ny_rating_df = ny_business_df.value_counts('Rating').to_frame()
ny_rating_df.columns = ['Num of Businesses']
ny_rating_df
# Out:
#         Num of Businesses
# Rating
# 4.5                   109
# 4.0                   104
# 5.0                    95
# 3.5                    59
# 3.0                    38
# 2.5                    26
# 1.0                    24
# 2.0                     6
# 1.5                     5

# %%
ny_rating_df['Ratings'] = ny_rating_df.index
ny_rating_df
# Out:
#         Num of Businesses  Ratings
# Rating
# 4.5                   109      4.5
# 4.0                   104      4.0
# 5.0                    95      5.0
# 3.5                    59      3.5
# 3.0                    38      3.0
# 2.5                    26      2.5
# 1.0                    24      1.0
# 2.0                     6      2.0
# 1.5                     5      1.5

# %%
ny_rating_df['Num of Businesses'].sum()
# Out:
# 466

# %%
ny_rating_df['percentages'] = (ny_rating_df['Num of Businesses']/ny_rating_df['Num of Businesses'].sum()) * 100
ny_rating_df
# Out:
#         Num of Businesses  Ratings  percentages
# Rating
# 4.5                   109      4.5    23.390558
# 4.0                   104      4.0    22.317597
# 5.0                    95      5.0    20.386266
# 3.5                    59      3.5    12.660944
# 3.0                    38      3.0     8.154506
# 2.5                    26      2.5     5.579399
# 1.0                    24      1.0     5.150215
# 2.0                     6      2.0     1.287554
# 1.5                     5      1.5     1.072961

# %%
combined_rating_df = pd.merge(dc_rating_df, ny_rating_df, how = 'outer', on='Ratings')
combined_rating_df.columns = ['DC Rating Totals', 'Rating', 'DC Ratings Percentages', 'NY Rating Totals','NY Ratings Percentages']
combined_rating_df
# Out:
#    DC Rating Totals  Rating  DC Ratings Percentages  NY Rating Totals  \
# 0              22.0     5.0               26.829268                95
# 1              22.0     4.5               26.829268               109
# 2              13.0     4.0               15.853659               104
# 3              12.0     3.5               14.634146                59
# 4               9.0     3.0               10.975610                38
# 5               3.0     2.5                3.658537                26
# 6               1.0     1.0                1.219512                24
# 7               NaN     2.0                     NaN                 6
# 8               NaN     1.5                     NaN                 5
#
#    NY Ratings Percentages
# 0               20.386266
# 1               23.390558
# 2               22.317597
# 3               12.660944
# 4                8.154506
# 5                5.579399
# 6                5.150215
# 7                1.287554
# ...

# %%
combined_rating_df = combined_rating_df.drop(['DC Rating Totals', 'NY Rating Totals'], axis=1)
combined_rating_df
# Out:
#    Rating  DC Ratings Percentages  NY Ratings Percentages
# 0     5.0               26.829268               20.386266
# 1     4.5               26.829268               23.390558
# 2     4.0               15.853659               22.317597
# 3     3.5               14.634146               12.660944
# 4     3.0               10.975610                8.154506
# 5     2.5                3.658537                5.579399
# 6     1.0                1.219512                5.150215
# 7     2.0                     NaN                1.287554
# 8     1.5                     NaN                1.072961

# %%
ax = combined_rating_df.plot.bar(x='Rating', figsize=(12, 8))

ax.set(xlabel="Rating", ylabel="Percentage", title ="Rating Percentages")
# Out:
# [Text(0.5, 0, 'Rating'),
#  Text(0, 0.5, 'Percentage'),
#  Text(0.5, 1.0, 'Rating Percentages')]

# %% [markdown]
# # Visualization 2 addressing
# # Use a bar chart to show percentage of businesses in each city which received ratings 1-5

# %%
dc_price_df = dc_business_df.value_counts('Price').to_frame()
dc_price_df.columns = ['Num of Businesses']
dc_price_df
# Out:
#        Num of Businesses
# Price
# 2.0                   37
# 3.0                    7
# 1.0                    5

# %%
dc_price_df['Prices'] = dc_price_df.index
dc_price_df
# Out:
#        Num of Businesses  Prices
# Price
# 2.0                   37     2.0
# 3.0                    7     3.0
# 1.0                    5     1.0

# %%
dc_rating_df['Num of Businesses'].sum()
# Out:
# 82

# %%
dc_price_df['percentages'] = (dc_price_df['Num of Businesses']/dc_price_df['Num of Businesses'].sum()) * 100
dc_price_df
# Out:
#        Num of Businesses  Prices  percentages
# Price
# 2.0                   37     2.0    75.510204
# 3.0                    7     3.0    14.285714
# 1.0                    5     1.0    10.204082

# %%
ny_price_df = ny_business_df.value_counts('Price').to_frame()
ny_price_df.columns = ['Num of Businesses']
ny_price_df
# Out:
#        Num of Businesses
# Price
# 2.0                  111
# 1.0                   29
# 3.0                   27
# 4.0                    6

# %%
ny_price_df['Prices'] = ny_price_df.index
ny_price_df
# Out:
#        Num of Businesses  Prices
# Price
# 2.0                  111     2.0
# 1.0                   29     1.0
# 3.0                   27     3.0
# 4.0                    6     4.0

# %%
ny_price_df['Num of Businesses'].sum()
# Out:
# 173

# %%
ny_price_df['percentages'] = (ny_price_df['Num of Businesses']/ny_price_df['Num of Businesses'].sum()) * 100
ny_price_df
# Out:
#        Num of Businesses  Prices  percentages
# Price
# 2.0                  111     2.0    64.161850
# 1.0                   29     1.0    16.763006
# 3.0                   27     3.0    15.606936
# 4.0                    6     4.0     3.468208

# %%
combined_price_df = pd.merge(dc_price_df, ny_price_df, how = 'outer', on='Prices')
combined_price_df.columns = ['DC Price Totals', 'Prices', 'DC Price Percentages', 'NY Price Totals','NY Price Percentages']
combined_price_df
# Out:
#    DC Price Totals  Prices  DC Price Percentages  NY Price Totals  \
# 0             37.0     2.0             75.510204              111
# 1              7.0     3.0             14.285714               27
# 2              5.0     1.0             10.204082               29
# 3              NaN     4.0                   NaN                6
#
#    NY Price Percentages
# 0             64.161850
# 1             15.606936
# 2             16.763006
# 3              3.468208

# %%
combined_price_df = combined_price_df.drop(['DC Price Totals', 'NY Price Totals'], axis=1)
combined_price_df
# Out:
#    Prices  DC Price Percentages  NY Price Percentages
# 0     2.0             75.510204             64.161850
# 1     3.0             14.285714             15.606936
# 2     1.0             10.204082             16.763006
# 3     4.0                   NaN              3.468208

# %%
ax = combined_price_df.plot.bar(x='Prices', figsize=(12, 8))

ax.set(xlabel="Price", ylabel="Percentage", title ="Price Percentages")
# Out:
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Percentage'),
#  Text(0.5, 1.0, 'Price Percentages')]

# %% [markdown]
# # Visualization 3
# # Boxplot displaying statistical data based on ratings.b

# %%
dc_boxrating_df = dc_business_df
dc_boxrating_df
# Out:
#                         ID                                     Name  \
# 0   Dn04j5YabUDWS7nUbpfZGg                          The Daily Rider
# 1   yGJ5jSQPSqp8i5rojSJnHQ                      Gearin' Up Bicycles
# 2   ATpgglOwwQUno5QhAEXc2g                            Bicycle Space
# 3   2q9eO68Q-PDAUUfdx-zvqw                           The Bike House
# 4   3tbIAR6xTrgSRO3m2da0Vg                        Conte's Bike Shop
# 5   dEUQ7Of8leYhaRF12qTswQ                           Takoma Bicycle
# 6   F0fMNrrBU3OKMdwfCL5mRA                         Upshift Workshop
# 7   obfGllLjyMkQ1iA_HtT1bQ                   Eric's Mobile Workshop
# 8   8mwlRyZ6FH2VW10tlHE2Qg                         Bicycle Pro Shop
# 9   Wqmx9LXrKzAUGeTZRV3XZg                    City Bikes Tenleytown
# 10  R2HBjZ0HYWIRquHMVBNA_w  Trek Bicycle Washington D.C. Georgetown
# 11  8eVGxeIopFn5hUX_YVkbGQ                       Nomad Bicycleworks
# 12  cU4Dg9ltf53aFoLBh8Ndkw                            Silver Cycles
# ...

# %%
dc_boxrating_df
# Out:
#                         ID                                     Name  \
# 0   Dn04j5YabUDWS7nUbpfZGg                          The Daily Rider
# 1   yGJ5jSQPSqp8i5rojSJnHQ                      Gearin' Up Bicycles
# 2   ATpgglOwwQUno5QhAEXc2g                            Bicycle Space
# 3   2q9eO68Q-PDAUUfdx-zvqw                           The Bike House
# 4   3tbIAR6xTrgSRO3m2da0Vg                        Conte's Bike Shop
# 5   dEUQ7Of8leYhaRF12qTswQ                           Takoma Bicycle
# 6   F0fMNrrBU3OKMdwfCL5mRA                         Upshift Workshop
# 7   obfGllLjyMkQ1iA_HtT1bQ                   Eric's Mobile Workshop
# 8   8mwlRyZ6FH2VW10tlHE2Qg                         Bicycle Pro Shop
# 9   Wqmx9LXrKzAUGeTZRV3XZg                    City Bikes Tenleytown
# 10  R2HBjZ0HYWIRquHMVBNA_w  Trek Bicycle Washington D.C. Georgetown
# 11  8eVGxeIopFn5hUX_YVkbGQ                       Nomad Bicycleworks
# 12  cU4Dg9ltf53aFoLBh8Ndkw                            Silver Cycles
# ...

# %%
dc_boxrating_2_df = dc_boxrating_df.value_counts('Rating')
dc_boxrating_2_df
# Out:
# Rating
# 5.0    22
# 4.5    22
# 4.0    13
# 3.5    12
# 3.0     9
# 2.5     3
# 1.0     1
# dtype: int64

# %%
dc_business_df.groupby('Rating')['Rating'].count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Rating'>

# %%
dc_boxrating_2_df.plot.box()
# Out:
# <AxesSubplot:>

# %%
#dc_boxrating_df = dc_business_df.value_counts('Rating').to_frame()
#dc_boxrating_df.columns = ['Num of Businesses']
#dc_boxrating_df
# Out:
#         Num of Businesses
# Rating
# 5.0                    22
# 4.5                    22
# 4.0                    13
# 3.5                    12
# 3.0                     9
# 2.5                     3
# 1.0                     1

# %%
#dc_boxrating_df['Ratings'] = dc_boxrating_df.index
#dc_boxrating_df
# Out:
#         Num of Businesses  Ratings
# Rating
# 5.0                    22      5.0
# 4.5                    22      4.5
# 4.0                    13      4.0
# 3.5                    12      3.5
# 3.0                     9      3.0
# 2.5                     3      2.5
# 1.0                     1      1.0

# %%
#ny_boxrating_df = ny_business_df.value_counts('Rating').to_frame()
#ny_boxrating_df.columns = ['Num of Businesses']
#ny_boxrating_df
# Out:
#         Num of Businesses
# Rating
# 4.5                   109
# 4.0                   104
# 5.0                    95
# 3.5                    59
# 3.0                    38
# 2.5                    26
# 1.0                    24
# 2.0                     6
# 1.5                     5

# %%
#ny_boxrating_df['Ratings'] = ny_boxrating_df.index
#ny_boxrating_df
# Out:
#         Num of Businesses  Ratings
# Rating
# 4.5                   109      4.5
# 4.0                   104      4.0
# 5.0                    95      5.0
# 3.5                    59      3.5
# 3.0                    38      3.0
# 2.5                    26      2.5
# 1.0                    24      1.0
# 2.0                     6      2.0
# 1.5                     5      1.5

# %%
#combined_boxrating_df = pd.merge(dc_boxrating_df, ny_boxrating_df, how = 'outer', on='Ratings')
#combined_boxrating_df.columns = ['DC Price Totals', 'Prices', 'DC Price Percentages', 'NY Price Totals','NY Price Percentages']
#combined_boxrating_df
# Out:
#    Num of Businesses_x  Ratings  Num of Businesses_y
# 0                 22.0      5.0                   95
# 1                 22.0      4.5                  109
# 2                 13.0      4.0                  104
# 3                 12.0      3.5                   59
# 4                  9.0      3.0                   38
# 5                  3.0      2.5                   26
# 6                  1.0      1.0                   24
# 7                  NaN      2.0                    6
# 8                  NaN      1.5                    5

# %%
#dc_boxrating_df.describe()
# Out:
#        Num of Businesses
# count           7.000000
# mean           11.714286
# std             8.280787
# min             1.000000
# 25%             6.000000
# 50%            12.000000
# 75%            17.500000
# max            22.000000

# %%
combined_boxrating_df.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ___

# %% [markdown]
# # Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
#while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
#    url_params['offset'] = cur
    #make your API call with the new offset number
#    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
#    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
#    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
#    cur += 20

# %%
dc_business_df.info()

# %%
dc_business_reviews_df.info()

# %%
combined = dc_business_df.merge(dc_business_reviews_df, left_on = 'ID', right_on = 'Business_ID', how = 'left')

# %%
combined.pivot_table(index = ['Name', 'Business_ID', 'Text'])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dc_business_df

# %%
dc_business_reviews_df

# %%
dc_business_df.info()

# %%
dc_business_df.corr()

# %%
len(dc_business_df['Price'])

# %%
dc_business_df.plot('Zip_Code', 'Rating', kind='bar');

# %%
fig, ax = plt.subplots()

x = dc_business_df['Rating']
y = dc_business_df['Price']


ax.scatter(x,y)

ax.set_title('Price Ratings Scatter Plot')

ax.set_xlabel('Ratings')
ax.set_ylabel('Price')

# %%
dc_business_df.plot('Zip_Code', 'Rating', kind='box');

# %%
dc_business_df.plot.hist();

# %%
dc_business_df.plot.box();

# %%
dc_business_df['Zip_Code'].unique()

# %%
dc_business_df.describe()

# %%
dc_business_df.describe()

# %%
business

# %%
dc_business_reviews_df.describe()
