# %% [markdown]
# # Getting Your Data From Yelp!

# %% [markdown]
# In order to make sure you are on track to completing the project, you will complete this workbook first. Below are steps that you need to take in order to make sure you have your data from yelp and are ready to analyze it. Your cohort lead will review this workbook with you the Wednesday before your project is due.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# You will be pulling data from the Yelp API to complete your analysis. The api, however, provides you with a lot of information that will not be pertinent to your analysis. YOu will pull data from the api and parse through it to keep only the data that you will need. In order to help you identify that information,look at the API documentation and understand what data the api will provide you.
#
# Identify which data fields you will want to keep for your analysis.
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ___

# %% [markdown]
# ## Part 2 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %% [markdown]
# - Write a function to make a call to the yelp API

# %%
import pandas as pd
import requests
import json

# %%
with open ('C:/Users/acumu/Documents/Flatiron/ds-east-042621-lectures/Phase_1/ds-apis-nbz32-main/.secrets/creds.json') as f:
    creds = json.load(f)

# %%
api_key = creds['key']
term = 'bike shop'
location = 'Washington DC'
SEARCH_LIMIT = 50
url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'offset': 0 
    }

# %%
def yelp_call(url_params, api_key):
    # your code to make the yelp call
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer ' + api_key}
    
    data = requests.get(url, headers = headers, params = url_params)
    return data

# %%
results = yelp_call(url_params, api_key)

# %%
type(results)
# Out:
# requests.models.Response

# %%
results.json()
# Out:
# {'businesses': [{'id': 'Dn04j5YabUDWS7nUbpfZGg',
#    'alias': 'the-daily-rider-washington-2',
#    'name': 'The Daily Rider',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jRfGdCPbaWmgXfRGc7FZWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-daily-rider-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 85,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9004, 'longitude': -76.99815},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '600 H St NE',
#     'address2': 'Ste D',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['600 H St NE', 'Ste D', 'Washington, DC 20002']},
#    'phone': '+12023960704',
#    'display_phone': '(202) 396-0704',
#    'distance': 3097.866378212942},
#   {'id': 'astpI6075yghzNk2XFiybA',
#    'alias': 'rollin-cycles-bicycle-shop-washington-2',
#    'name': 'Rollin Cycles Bicycle Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZCdE5Y9P82yXdF5LnPDHNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rollin-cycles-bicycle-shop-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 103,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.90779, 'longitude': -77.03236},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1314 14th St NW',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20005',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1314 14th St NW', 'Ste A', 'Washington, DC 20005']},
#    'phone': '+12025253712',
#    'display_phone': '(202) 525-3712',
#    'distance': 413.2097572293308},
#   {'id': 'F0fMNrrBU3OKMdwfCL5mRA',
#    'alias': 'upshift-workshop-washington',
#    'name': 'Upshift Workshop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aU10l1169G8Xk-SlkX0Htw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upshift-workshop-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 6,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'specialtyschools', 'title': 'Specialty Schools'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.91409, 'longitude': -77.02021},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20001',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['Washington, DC 20001']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1008.7991422520444},
#   {'id': 'YvDCWE1O_Q6JLMiKHb4tGQ',
#    'alias': 'city-bikes-adams-morgan-washington',
#    'name': 'City Bikes - Adams Morgan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Z0FT0D5CEpoLfhjWR_dKXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-bikes-adams-morgan-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 257,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.92319, 'longitude': -77.04116},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '2501 Champlain St NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20009',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['2501 Champlain St NW', 'Washington, DC 20009']},
#    'phone': '+12022651564',
#    'display_phone': '(202) 265-1564',
#    'distance': 1607.9170708306572},
#   {'id': 'ATpgglOwwQUno5QhAEXc2g',
#    'alias': 'bicycle-space-washington',
#    'name': 'Bicycle Space',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AXuIf9z9Ygvpc82VNhl6Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bicycle-space-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 54,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.91555288609606, 'longitude': -76.9819596},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1512 Okie St NE',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1512 Okie St NE', 'Washington, DC 20002']},
#    'phone': '+12028539390',
#    'display_phone': '(202) 853-9390',
#    'distance': 4238.354076716037},
#   {'id': 'OxnwyBMJN43a_5UHL3UHWQ',
#    'alias': 'velofix-washington',
#    'name': 'velofix',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zQ4VQaYd4JBpgGm7HbpCig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velofix-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 39,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.9104423522949,
#     'longitude': -77.0177383422852},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20001',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['Washington, DC 20001']},
#    'phone': '+18558356349',
#    'display_phone': '(855) 835-6349',
#    'distance': 1008.7991422520444},
#   {'id': '3tbIAR6xTrgSRO3m2da0Vg',
#    'alias': 'contes-bike-shop-washington-2',
#    'name': "Conte's Bike Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jSMQrrd35k0t-pFEb_Cylg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/contes-bike-shop-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 48,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.8755404, 'longitude': -77.0006849},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1331 4th St SE',
#     'address2': 'Ste 107',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20003',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1331 4th St SE', 'Ste 107', 'Washington, DC 20003']},
#    'phone': '+12025589866',
#    'display_phone': '(202) 558-9866',
#    'distance': 4849.692727751653},
#   {'id': '2q9eO68Q-PDAUUfdx-zvqw',
#    'alias': 'the-bike-house-washington',
#    'name': 'The Bike House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g3xVM9XSN1UlyfM1uYNCFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bike-house-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 7,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.94157, 'longitude': -77.02776},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1240 Upshur St NW',
#     'address2': '',
#     'address3': "Annie's Hardware",
#     'city': 'Washington, DC',
#     'zip_code': '20542',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1240 Upshur St NW',
#      "Annie's Hardware",
#      'Washington, DC 20542']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3376.411706122324},
#   {'id': 'gmXiBdjkKVTGM-4mU8Sepw',
#    'alias': 'contes-bike-shop-washington-4',
#    'name': "Conte's Bike Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aMwCGAgQo8zoQwt_KUOtGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/contes-bike-shop-washington-4?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 7,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.91094, 'longitude': -77.03262},
#    'transactions': [],
#    'location': {'address1': '1412 Q St NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20009',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1412 Q St NW', 'Washington, DC 20009']},
#    'phone': '+12023872453',
#    'display_phone': '(202) 387-2453',
#    'distance': 173.23918189983158},
#   {'id': 'yGJ5jSQPSqp8i5rojSJnHQ',
#    'alias': 'gearin-up-bicycles-washington',
#    'name': "Gearin' Up Bicycles",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pxeTcG_pOzRq9Bir2T155A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gearin-up-bicycles-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 24,
#    'categories': [{'alias': 'nonprofit',
#      'title': 'Community Service/Non-Profit'},
#     {'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9135399, 'longitude': -77.0011978},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '314 Randolph Pl NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['314 Randolph Pl NE', 'Washington, DC 20002']},
#    'phone': '+12027805174',
#    'display_phone': '(202) 780-5174',
#    'distance': 2558.7296500991483},
#   {'id': 'NBsk50CXW85OFAkxnOao8Q',
#    'alias': 'district-cycle-works-washington-5',
#    'name': 'District Cycle Works',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tmMk40Mt7m0qrTgksqLc0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/district-cycle-works-washington-5?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 12,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9095191955566,
#     'longitude': -77.0549850463867},
#    'transactions': [],
#    'location': {'address1': '2603 P St NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20007',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['2603 P St NW', 'Washington, DC 20007']},
#    'phone': '+12026433040',
#    'display_phone': '(202) 643-3040',
#    'distance': 2116.5099409641434},
#   {'id': 'obfGllLjyMkQ1iA_HtT1bQ',
#    'alias': 'erics-mobile-workshop-washington',
#    'name': "Eric's Mobile Workshop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8A_MK1YiaPmesBlDRjtTPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erics-mobile-workshop-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 6,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.895394132053276,
#     'longitude': -76.9787847888091},
#    'transactions': [],
#    'location': {'address1': '417 18th St NE',
#     'address2': None,
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['417 18th St NE', 'Washington, DC 20002']},
#    'phone': '+12023021925',
#    'display_phone': '(202) 302-1925',
#    'distance': 4822.856421231606},
#   {'id': '8eVGxeIopFn5hUX_YVkbGQ',
#    'alias': 'nomad-bicycleworks-washington-3',
#    'name': 'Nomad Bicycleworks',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wjXRN6okMjyAltJpqCVZ2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nomad-bicycleworks-washington-3?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 21,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.93762, 'longitude': -76.99156},
#    'transactions': [],
#    'location': {'address1': 'Michigan Ave NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20017',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['Michigan Ave NE', 'Washington, DC 20017']},
#    'phone': '+12023225020',
#    'display_phone': '(202) 322-5020',
#    'distance': 4320.584530601891},
#   {'id': 'R2HBjZ0HYWIRquHMVBNA_w',
#    'alias': 'trek-bicycle-washington-d-c-georgetown-washington-2',
#    'name': 'Trek Bicycle Washington D.C. Georgetown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3Qc4eSI-6kCX5KW18Ino1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trek-bicycle-washington-d-c-georgetown-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 116,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.90526, 'longitude': -77.06836},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3411 M St NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20007',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['3411 M St NW', 'Washington, DC 20007']},
#    'phone': '+12029653601',
#    'display_phone': '(202) 965-3601',
#    'distance': 3331.086453086722},
#   {'id': '8mwlRyZ6FH2VW10tlHE2Qg',
#    'alias': 'bicycle-pro-shop-washington',
#    'name': 'Bicycle Pro Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CWFpQO9D8anPjp5dedSXrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bicycle-pro-shop-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 96,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.905258, 'longitude': -77.068077},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3403 M St NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20007',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['3403 M St NW', 'Washington, DC 20007']},
#    'phone': '+12023370311',
#    'display_phone': '(202) 337-0311',
#    'distance': 3307.5817505554032},
#   {'id': '2NvqroYky8n4wO6agru4Kw',
#    'alias': 'bikes-and-skates-capitol-heights',
#    'name': 'Bikes & Skates',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tIHIk0Fzuf3Mmg48wfiTjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bikes-and-skates-capitol-heights?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 38,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'skatingrinks', 'title': 'Skating Rinks'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.87955, 'longitude': -76.8582},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '712 Ritchie Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Capitol Heights',
#     'zip_code': '20743',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['712 Ritchie Rd', 'Capitol Heights, MD 20743']},
#    'phone': '+13013332453',
#    'display_phone': '(301) 333-2453',
#    'distance': 15342.36603304319},
#   {'id': 'Wqmx9LXrKzAUGeTZRV3XZg',
#    'alias': 'city-bikes-tenleytown-washington',
#    'name': 'City Bikes Tenleytown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1oF7SL6PBNNzCqr7X4jnfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-bikes-tenleytown-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 44,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.95243, 'longitude': -77.08178},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4810 Wisconsin Ave NW',
#     'address2': '',
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20016',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['4810 Wisconsin Ave NW', 'Washington, DC 20016']},
#    'phone': '+12025580055',
#    'display_phone': '(202) 558-0055',
#    'distance': 6370.388234025397},
#   {'id': 'Nnfhnuqv2WTeHRs_mDFPRA',
#    'alias': 'big-wheel-bikes-alexandria',
#    'name': 'Big Wheel Bikes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/whVGhGnyUGUIp3Q5K1umsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-wheel-bikes-alexandria?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 165,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8028907775879,
#     'longitude': -77.0399475097656},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2 Prince St',
#     'address2': '',
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22314',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['2 Prince St', 'Alexandria, VA 22314']},
#    'phone': '+17037392300',
#    'display_phone': '(703) 739-2300',
#    'distance': 12081.53215192056},
#   {'id': 'jQoYuCkGdeGNRfif4JlYDw',
#    'alias': 'the-old-bike-shop-arlington',
#    'name': 'The Old Bike Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iyXz1KPaUSOI8gVyRQSD4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-old-bike-shop-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 87,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8809493, 'longitude': -77.090245},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2647 N Pershing Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['2647 N Pershing Dr', 'Arlington, VA 22201']},
#    'phone': '+15713121730',
#    'display_phone': '(571) 312-1730',
#    'distance': 6163.849882413538},
#   {'id': 'dEUQ7Of8leYhaRF12qTswQ',
#    'alias': 'takoma-bicycle-takoma-park',
#    'name': 'Takoma Bicycle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rS79JxJrM9nXLLZcwjUEPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/takoma-bicycle-takoma-park?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 63,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.97505, 'longitude': -77.01152},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7030 Carroll Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Takoma Park',
#     'zip_code': '20912',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['7030 Carroll Ave', 'Takoma Park, MD 20912']},
#    'phone': '+13012700202',
#    'display_phone': '(301) 270-0202',
#    'distance': 7279.667521878337},
#   {'id': '-zIt1sAhZpndaiWjMFVGcA',
#    'alias': 'griffin-cycle-bethesda-2',
#    'name': 'Griffin Cycle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YT2YxsQ2gS5vJRymh3YsFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/griffin-cycle-bethesda-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 107,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.980987, 'longitude': -77.0997469},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4933 Bethesda Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bethesda',
#     'zip_code': '20814',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['4933 Bethesda Ave', 'Bethesda, MD 20814']},
#    'phone': '+13016566188',
#    'display_phone': '(301) 656-6188',
#    'distance': 9786.280544826244},
#   {'id': 'uq9j3G6MJtd_Mv5rfF5oRQ',
#    'alias': 'pedego-electric-bikes-alexandria-alexandria-2',
#    'name': 'Pedego Electric Bikes Alexandria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iioU8_g_DwAURzGtgnrOZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pedego-electric-bikes-alexandria-alexandria-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 37,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.80582466318016,
#     'longitude': -77.04137430037159},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '210 N Lee St',
#     'address2': 'Unit 102',
#     'address3': None,
#     'city': 'Alexandria',
#     'zip_code': '22314',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['210 N Lee St', 'Unit 102', 'Alexandria, VA 22314']},
#    'phone': '+15713125168',
#    'display_phone': '(571) 312-5168',
#    'distance': 11764.370521566729},
#   {'id': 'Sb_3F7bcGYLGjUssQfiP6w',
#    'alias': 'riide-washington',
#    'name': 'Riide',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hE2464NqAMkHYgvnJfcU2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/riide-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 5,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.9220816, 'longitude': -76.9989568},
#    'transactions': [],
#    'location': {'address1': '524 Rhode Island Ave NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20001',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['524 Rhode Island Ave NE', 'Washington, DC 20001']},
#    'phone': '+12028001549',
#    'display_phone': '(202) 800-1549',
#    'distance': 2992.0730215799817},
#   {'id': 'CZSLn0w5xUESdprbfINn8w',
#    'alias': 'proteus-bicycles-college-park',
#    'name': 'Proteus Bicycles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0Udtiobo2cg2UC41OCXP3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/proteus-bicycles-college-park?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 86,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.014772, 'longitude': -76.920292},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9827 Rhode Island Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'College Park',
#     'zip_code': '20740',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['9827 Rhode Island Ave', 'College Park, MD 20740']},
#    'phone': '+13014412928',
#    'display_phone': '(301) 441-2928',
#    'distance': 14947.159535656447},
#   {'id': 'p9U34BqsfvgY2zKTW6fFkg',
#    'alias': 'electricitybikes-washington',
#    'name': 'ElectriCityBikes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R25a7kGDVUGfyRQn2f11Hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/electricitybikes-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 20,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.95209, 'longitude': -77.0817},
#    'transactions': [],
#    'location': {'address1': '4800 Wisconsin Ave Nw B',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20016',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['4800 Wisconsin Ave Nw B', 'Washington, DC 20016']},
#    'phone': '+12025580055',
#    'display_phone': '(202) 558-0055',
#    'distance': 6332.531612988286},
#   {'id': 'iILgX1Q8tc29Onj8OgdKOA',
#    'alias': 'bike-doctor-of-waldorf-waldorf-2',
#    'name': 'Bike Doctor of Waldorf',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ng1F-lMj0wwriK1ptVr0nQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bike-doctor-of-waldorf-waldorf-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 59,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.622951, 'longitude': -76.904803},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3200 Leonardtown Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Waldorf',
#     'zip_code': '20601',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['3200 Leonardtown Rd', 'Waldorf, MD 20601']},
#    'phone': '+13019329980',
#    'display_phone': '(301) 932-9980',
#    'distance': 33868.91545559623},
#   {'id': 'MnV2zaZSXToe-vpkTccZ4Q',
#    'alias': 'bike-and-roll-dc-washington-2',
#    'name': 'Bike And Roll DC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rLcWH4iDU7jprV3IXWYL0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bike-and-roll-dc-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 328,
#    'categories': [{'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'tours', 'title': 'Tours'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.884457, 'longitude': -77.024737},
#    'transactions': [],
#    'location': {'address1': "955 L'Enfant Plz SW",
#     'address2': 'Ste 905',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20024',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ["955 L'Enfant Plz SW",
#      'Ste 905',
#      'Washington, DC 20024']},
#    'phone': '+12028422453',
#    'display_phone': '(202) 842-2453',
#    'distance': 3027.4915822865332},
#   {'id': 'cU4Dg9ltf53aFoLBh8Ndkw',
#    'alias': 'silver-cycles-silver-spring',
#    'name': 'Silver Cycles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/70DaRZVfpsMuA6SWFKj67w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/silver-cycles-silver-spring?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 89,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.992789, 'longitude': -77.0279302},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8307 Dixon Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Silver Spring',
#     'zip_code': '20910',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['8307 Dixon Ave', 'Silver Spring, MD 20910']},
#    'phone': '+13015851889',
#    'display_phone': '(301) 585-1889',
#    'distance': 9064.896291824756},
#   {'id': 'SVk-4xwL9tA9TSB0ZnWFBA',
#    'alias': 'big-wheel-bikes-washington',
#    'name': 'Big Wheel Bikes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FaO_MkDebVcfU-syRQM6oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-wheel-bikes-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 62,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.90463, 'longitude': -77.06618},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1034 33rd St NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20007',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1034 33rd St NW', 'Washington, DC 20007']},
#    'phone': '+12023370254',
#    'display_phone': '(202) 337-0254',
#    'distance': 3162.718899591382},
#   {'id': 'AjIOtN_0SlyY2dgVuBbwhg',
#    'alias': 'jafe-cycling-capitol-heights-2',
#    'name': 'Jafe Cycling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MUmYZzlcCL8YWAiMyKG-nA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jafe-cycling-capitol-heights-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 5,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.8836288452148,
#     'longitude': -76.9007034301758},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Capitol Heights',
#     'zip_code': '20743',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['Capitol Heights, MD 20743']},
#    'phone': '+12029534210',
#    'display_phone': '(202) 953-4210',
#    'distance': 10355.146808177007},
#   {'id': 'DPUPnCnPwCdcFl6U7nBNsw',
#    'alias': 'contes-bike-shop-arlington-2',
#    'name': "Conte's Bike Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/uylNus_YH9nkHmTatgaPXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/contes-bike-shop-arlington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 67,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8825512965536,
#     'longitude': -77.1016142851839},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3449 Wilson Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3449 Wilson Blvd', 'Arlington, VA 22201']},
#    'phone': '+15718003126',
#    'display_phone': '(571) 800-3126',
#    'distance': 6923.915475619912},
#   {'id': '4wh6LsjL0Cki3IfJbSSzrA',
#    'alias': 'bicyclespace-washington-washington',
#    'name': 'BicycleSPACE - Washington',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_AFgjz1S8xvoI9mm46DLFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bicyclespace-washington-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 19,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.915561, 'longitude': -76.9819596},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1512 Okie St NE',
#     'address2': '',
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1512 Okie St NE', 'Washington, DC 20002']},
#    'phone': '+12028539390',
#    'display_phone': '(202) 853-9390',
#    'distance': 4238.45475100731},
#   {'id': 'ky_3ss5asDpYqb8L1x3P-Q',
#    'alias': 'spokes-etc-bicycles-alexandria-6',
#    'name': 'Spokes Etc. Bicycles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/w5dDL7Nn5dJaHFXF2q_umQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spokes-etc-bicycles-alexandria-6?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 136,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.82927, 'longitude': -77.08573},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1545 N Quaker Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22302',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['1545 N Quaker Ln', 'Alexandria, VA 22302']},
#    'phone': '+17038202200',
#    'display_phone': '(703) 820-2200',
#    'distance': 10243.39054337174},
#   {'id': 'RfsW8djTUV8TfDHy9TxfUw',
#    'alias': 'rei-washington-4',
#    'name': 'REI',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iKMH151QB-vLfQZyMCJPBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rei-washington-4?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 119,
#    'categories': [{'alias': 'sportgoods', 'title': 'Sporting Goods'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.9055151, 'longitude': -77.0028494},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '201 M St NE',
#     'address2': '',
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['201 M St NE', 'Washington, DC 20002']},
#    'phone': '+12025432040',
#    'display_phone': '(202) 543-2040',
#    'distance': 2518.0874958788154},
#   {'id': 'WXuilvVlx0MzBqX1e6GO6A',
#    'alias': 'rapha-dc-washington',
#    'name': 'Rapha DC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TJoeuB5df6YJEfrE7GrLdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rapha-dc-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 7,
#    'categories': [{'alias': 'sportswear', 'title': 'Sports Wear'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9037999, 'longitude': -77.0635099},
#    'transactions': [],
#    'location': {'address1': '3210 Grace St',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20007',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['3210 Grace St', 'Washington, DC 20007']},
#    'phone': '+12027331692',
#    'display_phone': '(202) 733-1692',
#    'distance': 2963.8342173106244},
#   {'id': 'xSzKaAq6vgZZDn3S5-V9Hw',
#    'alias': 'arrow-bicycle-hyattsville',
#    'name': 'Arrow Bicycle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RnXjN_rULoEwhgQt3kRqtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arrow-bicycle-hyattsville?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 32,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.95183, 'longitude': -76.94098},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5108 Baltimore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Hyattsville',
#     'zip_code': '20781',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['5108 Baltimore Ave', 'Hyattsville, MD 20781']},
#    'phone': '+13015319250',
#    'display_phone': '(301) 531-9250',
#    'distance': 8986.025301026322},
#   {'id': 'q-pvnWBgielD--bA81hLFQ',
#    'alias': 'district-cycles-washington',
#    'name': 'District Cycles',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/district-cycles-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 6,
#    'categories': [{'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.95504, 'longitude': -77.06946},
#    'transactions': [],
#    'location': {'address1': '5001 Connecticut Ave NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20008',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['5001 Connecticut Ave NW', 'Washington, DC 20008']},
#    'phone': '+12024926649',
#    'display_phone': '(202) 492-6649',
#    'distance': 5917.963111887937},
#   {'id': 'wdQepvuFBpPKJ1R6titiNA',
#    'alias': 'papillon-cycles-arlington',
#    'name': 'Papillon Cycles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C3PNmrERnSRXsCgdCYqXdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papillon-cycles-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 93,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.862618, 'longitude': -77.086905},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2805 Columbia Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22204',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['2805 Columbia Pike', 'Arlington, VA 22204']},
#    'phone': '+17039209494',
#    'display_phone': '(703) 920-9494',
#    'distance': 7280.853067658953},
#   {'id': 'NM9NmHZ_KbNsmrfrP3Whvg',
#    'alias': 'trek-bicycle-rockville-rockville',
#    'name': 'Trek Bicycle Rockville',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OvcnOHI4bB1myUp0YFg2MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trek-bicycle-rockville-rockville?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 42,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.0624447, 'longitude': -77.1177493},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5750 Fishers Ln',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Rockville',
#     'zip_code': '20852',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['5750 Fishers Ln', 'Ste A', 'Rockville, MD 20852']},
#    'phone': '+13014240990',
#    'display_phone': '(301) 424-0990',
#    'distance': 18411.17486834801},
#   {'id': '1q-0mrzsr1EIF5U0aTPFXQ',
#    'alias': 'probike-fc-falls-church',
#    'name': 'ProBike FC',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aoohCDJ15yDX_v1NxsIC0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/probike-fc-falls-church?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 25,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.88027, 'longitude': -77.17193},
#    'transactions': [],
#    'location': {'address1': '116 E Fairfax St',
#     'address2': None,
#     'address3': '',
#     'city': 'Falls Church',
#     'zip_code': '22046',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['116 E Fairfax St', 'Falls Church, VA 22046']},
#    'phone': '+17038541427',
#    'display_phone': '(703) 854-1427',
#    'distance': 12683.669692968206},
#   {'id': 'Z97inykgHENrsBTg1S__wA',
#    'alias': 'contes-bike-shop-washington-3',
#    'name': "Conte's Bike Shop",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fTQOMQ4U_nYFqYQ99x13Mg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/contes-bike-shop-washington-3?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 17,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.93508, 'longitude': -77.07298},
#    'transactions': [],
#    'location': {'address1': '3410 Wisconsin Ave NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20016',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['3410 Wisconsin Ave NW', 'Washington, DC 20016']},
#    'phone': '+12023910804',
#    'display_phone': '(202) 391-0804',
#    'distance': 4517.968264438373},
#   {'id': 'YvguUf5tL6HDElwIAhjZ4Q',
#    'alias': 'wheel-nuts-bike-shop-alexandria',
#    'name': 'Wheel Nuts Bike Shop',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/w0Tz7L_mlPdFh_4wQXxfbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wheel-nuts-bike-shop-alexandria?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 135,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.8135109, 'longitude': -77.040863},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 Montgomery St',
#     'address2': '',
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22314',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['302 Montgomery St', 'Alexandria, VA 22314']},
#    'phone': '+17035485116',
#    'display_phone': '(703) 548-5116',
#    'distance': 10913.802794170024},
#   {'id': 'CmJmSF3Cw0lxuxwusJV8_Q',
#    'alias': 'trek-bicycle-arlington-clarendon-arlington-2',
#    'name': 'Trek Bicycle Arlington Clarendon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i-ozRqPF71bNKv19TNKW7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trek-bicycle-arlington-clarendon-arlington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 171,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.88939, 'longitude': -77.09165},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '2731 Wilson Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['2731 Wilson Blvd', 'Arlington, VA 22201']},
#    'phone': '+17033120007',
#    'display_phone': '(703) 312-0007',
#    'distance': 5806.494485033087},
#   {'id': 'xTrJ9Q5tNAAkj5p9Du7yRw',
#    'alias': 'vélocity-bicycle-cooperative-alexandria',
#    'name': 'VéloCity Bicycle Cooperative',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Vxb8xcgyadzbenmDF1Y8iA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/v%C3%A9locity-bicycle-cooperative-alexandria?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 65,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.8253, 'longitude': -77.05834},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2111 Mt Vernon Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22301',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['2111 Mt Vernon Ave', 'Alexandria, VA 22301']},
#    'phone': '+17035491108',
#    'display_phone': '(703) 549-1108',
#    'distance': 9853.62026518473},
#   {'id': 'AsOcjvsQQfADGDft5LmzpQ',
#    'alias': 'fleet-feet-washington',
#    'name': 'Fleet Feet',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/L4YRTZX2_3YX7niG-T_TtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fleet-feet-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 150,
#    'categories': [{'alias': 'shoes', 'title': 'Shoe Stores'},
#     {'alias': 'sportswear', 'title': 'Sports Wear'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9214859008789,
#     'longitude': -77.0439224243164},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1841 Columbia Rd NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20009',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1841 Columbia Rd NW', 'Washington, DC 20009']},
#    'phone': '+12023873888',
#    'display_phone': '(202) 387-3888',
#    'distance': 1621.3290456947207},
#   {'id': '3mFZjswCTJ2X4MRBNRdSjA',
#    'alias': 'the-bicycle-place-silver-spring',
#    'name': 'The Bicycle Place',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/u_JwiKlgXoTfPBkiwkVkbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-bicycle-place-silver-spring?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 43,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.00623, 'longitude': -77.04948},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9168 Brookville Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Silver Spring',
#     'zip_code': '20910',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['9168 Brookville Rd', 'Silver Spring, MD 20910']},
#    'phone': '+13015886160',
#    'display_phone': '(301) 588-6160',
#    'distance': 10680.945420911501},
#   {'id': 'htdy8C1Rdz9baITZemFqgg',
#    'alias': 'evo-cycle-works-rockville-4',
#    'name': 'Evo Cycle Works',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZXFmI6-vrw2tT-qox7i-RQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evo-cycle-works-rockville-4?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 35,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.093622, 'longitude': -77.134568},
#    'transactions': [],
#    'location': {'address1': '1172 Taft St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rockville',
#     'zip_code': '20850',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['1172 Taft St', 'Rockville, MD 20850']},
#    'phone': '+12406174053',
#    'display_phone': '(240) 617-4053',
#    'distance': 22173.97627460901},
#   {'id': 'wuFuQt1lI0kvy8ZaCie8WQ',
#    'alias': 'phoenix-bikes-arlington',
#    'name': 'Phoenix Bikes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AlPSINuggERA2HODfEMh5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/phoenix-bikes-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 28,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.856241, 'longitude': -77.1000176},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '909 S Dinwiddie St',
#     'address2': None,
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22204',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['909 S Dinwiddie St', 'Arlington, VA 22204']},
#    'phone': '+17035757762',
#    'display_phone': '(703) 575-7762',
#    'distance': 8575.241096360236},
#   {'id': '0KQG1qvOX8w7lPWa61w8OQ',
#    'alias': 'big-wheel-bikes-arlington',
#    'name': 'Big Wheel Bikes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q8xMXB3u0H6C4BnfX90F6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-wheel-bikes-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 94,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.89667, 'longitude': -77.09622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3119 Lee Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3119 Lee Hwy', 'Arlington, VA 22201']},
#    'phone': '+17035221110',
#    'display_phone': '(703) 522-1110',
#    'distance': 5918.1857933962765},
#   {'id': 'd50OtT7Y4N5l3OeBtRwIdA',
#    'alias': 'big-wheel-bikes-bethesda',
#    'name': 'Big Wheel Bikes',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Rn7L0FmaiBEMc4wfMxcZiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-wheel-bikes-bethesda?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 50,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.978526358785,
#     'longitude': -77.0985233774307},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6917 Arlington Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bethesda',
#     'zip_code': '20814',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['6917 Arlington Rd', 'Bethesda, MD 20814']},
#    'phone': '+13016520192',
#    'display_phone': '(301) 652-0192',
#    'distance': 9505.516360603122}],
#  'total': 146,
#  'region': {'center': {'longitude': -77.0306396484375,
#    'latitude': 38.911293573163775}}}

# %%
data_df = pd.DataFrame(results.json()['businesses'])

# %%
data_df
# Out:
#                         id                                              alias  \
# 0   Dn04j5YabUDWS7nUbpfZGg                       the-daily-rider-washington-2
# 1   astpI6075yghzNk2XFiybA            rollin-cycles-bicycle-shop-washington-2
# 2   F0fMNrrBU3OKMdwfCL5mRA                        upshift-workshop-washington
# 3   YvDCWE1O_Q6JLMiKHb4tGQ                 city-bikes-adams-morgan-washington
# 4   ATpgglOwwQUno5QhAEXc2g                           bicycle-space-washington
# 5   OxnwyBMJN43a_5UHL3UHWQ                                 velofix-washington
# 6   3tbIAR6xTrgSRO3m2da0Vg                      contes-bike-shop-washington-2
# 7   2q9eO68Q-PDAUUfdx-zvqw                          the-bike-house-washington
# 8   gmXiBdjkKVTGM-4mU8Sepw                      contes-bike-shop-washington-4
# 9   yGJ5jSQPSqp8i5rojSJnHQ                      gearin-up-bicycles-washington
# 10  NBsk50CXW85OFAkxnOao8Q                  district-cycle-works-washington-5
# 11  obfGllLjyMkQ1iA_HtT1bQ                   erics-mobile-workshop-washington
# 12  8eVGxeIopFn5hUX_YVkbGQ                    nomad-bicycleworks-washington-3
# 13  R2HBjZ0HYWIRquHMVBNA_w  trek-bicycle-washington-d-c-georgetown-washing...
# 14  8mwlRyZ6FH2VW10tlHE2Qg                        bicycle-pro-shop-washington
# 15  2NvqroYky8n4wO6agru4Kw                   bikes-and-skates-capitol-heights
# 16  Wqmx9LXrKzAUGeTZRV3XZg                   city-bikes-tenleytown-washington
# 17  Nnfhnuqv2WTeHRs_mDFPRA                         big-wheel-bikes-alexandria
# 18  jQoYuCkGdeGNRfif4JlYDw                        the-old-bike-shop-arlington
# 19  dEUQ7Of8leYhaRF12qTswQ                         takoma-bicycle-takoma-park
# 20  -zIt1sAhZpndaiWjMFVGcA                           griffin-cycle-bethesda-2
# 21  uq9j3G6MJtd_Mv5rfF5oRQ      pedego-electric-bikes-alexandria-alexandria-2
# 22  Sb_3F7bcGYLGjUssQfiP6w                                   riide-washington
# 23  CZSLn0w5xUESdprbfINn8w                      proteus-bicycles-college-park
# 24  p9U34BqsfvgY2zKTW6fFkg                        electricitybikes-washington
# 25  iILgX1Q8tc29Onj8OgdKOA                   bike-doctor-of-waldorf-waldorf-2
# 26  MnV2zaZSXToe-vpkTccZ4Q                      bike-and-roll-dc-washington-2
# 27  cU4Dg9ltf53aFoLBh8Ndkw                        silver-cycles-silver-spring
# 28  SVk-4xwL9tA9TSB0ZnWFBA                         big-wheel-bikes-washington
# 29  AjIOtN_0SlyY2dgVuBbwhg                     jafe-cycling-capitol-heights-2
# 30  DPUPnCnPwCdcFl6U7nBNsw                       contes-bike-shop-arlington-2
# 31  4wh6LsjL0Cki3IfJbSSzrA                 bicyclespace-washington-washington
# 32  ky_3ss5asDpYqb8L1x3P-Q                   spokes-etc-bicycles-alexandria-6
# 33  RfsW8djTUV8TfDHy9TxfUw                                   rei-washington-4
# 34  WXuilvVlx0MzBqX1e6GO6A                                rapha-dc-washington
# 35  xSzKaAq6vgZZDn3S5-V9Hw                          arrow-bicycle-hyattsville
# 36  q-pvnWBgielD--bA81hLFQ                         district-cycles-washington
# 37  wdQepvuFBpPKJ1R6titiNA                          papillon-cycles-arlington
# 38  NM9NmHZ_KbNsmrfrP3Whvg                   trek-bicycle-rockville-rockville
# 39  1q-0mrzsr1EIF5U0aTPFXQ                            probike-fc-falls-church
# 40  Z97inykgHENrsBTg1S__wA                      contes-bike-shop-washington-3
# 41  YvguUf5tL6HDElwIAhjZ4Q                    wheel-nuts-bike-shop-alexandria
# 42  CmJmSF3Cw0lxuxwusJV8_Q       trek-bicycle-arlington-clarendon-arlington-2
# 43  xTrJ9Q5tNAAkj5p9Du7yRw            vélocity-bicycle-cooperative-alexandria
# 44  AsOcjvsQQfADGDft5LmzpQ                              fleet-feet-washington
# 45  3mFZjswCTJ2X4MRBNRdSjA                    the-bicycle-place-silver-spring
# 46  htdy8C1Rdz9baITZemFqgg                        evo-cycle-works-rockville-4
# 47  wuFuQt1lI0kvy8ZaCie8WQ                            phoenix-bikes-arlington
# 48  0KQG1qvOX8w7lPWa61w8OQ                          big-wheel-bikes-arlington
# 49  d50OtT7Y4N5l3OeBtRwIdA                           big-wheel-bikes-bethesda
#
#                                        name  \
# 0                           The Daily Rider
# 1                Rollin Cycles Bicycle Shop
# 2                          Upshift Workshop
# 3                 City Bikes - Adams Morgan
# 4                             Bicycle Space
# 5                                   velofix
# 6                         Conte's Bike Shop
# 7                            The Bike House
# 8                         Conte's Bike Shop
# 9                       Gearin' Up Bicycles
# 10                     District Cycle Works
# 11                   Eric's Mobile Workshop
# 12                       Nomad Bicycleworks
# 13  Trek Bicycle Washington D.C. Georgetown
# 14                         Bicycle Pro Shop
# 15                           Bikes & Skates
# 16                    City Bikes Tenleytown
# 17                          Big Wheel Bikes
# 18                        The Old Bike Shop
# 19                           Takoma Bicycle
# 20                            Griffin Cycle
# 21         Pedego Electric Bikes Alexandria
# 22                                    Riide
# 23                         Proteus Bicycles
# 24                         ElectriCityBikes
# 25                   Bike Doctor of Waldorf
# 26                         Bike And Roll DC
# 27                            Silver Cycles
# 28                          Big Wheel Bikes
# 29                             Jafe Cycling
# 30                        Conte's Bike Shop
# 31                BicycleSPACE - Washington
# 32                     Spokes Etc. Bicycles
# 33                                      REI
# 34                                 Rapha DC
# 35                            Arrow Bicycle
# 36                          District Cycles
# 37                          Papillon Cycles
# 38                   Trek Bicycle Rockville
# 39                               ProBike FC
# 40                        Conte's Bike Shop
# 41                     Wheel Nuts Bike Shop
# 42         Trek Bicycle Arlington Clarendon
# 43             VéloCity Bicycle Cooperative
# 44                               Fleet Feet
# 45                        The Bicycle Place
# 46                          Evo Cycle Works
# 47                            Phoenix Bikes
# 48                          Big Wheel Bikes
# 49                          Big Wheel Bikes
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/jRfGdC...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/ZCdE5Y...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/aU10l1...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/Z0FT0D...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/AXuIf9...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/zQ4VQa...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/jSMQrr...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/g3xVM9...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/aMwCGA...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/pxeTcG...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/tmMk40...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/8A_MK1...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/wjXRN6...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/3Qc4eS...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/CWFpQO...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/tIHIk0...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/1oF7SL...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/whVGhG...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/iyXz1K...      False
# 19  https://s3-media1.fl.yelpcdn.com/bphoto/rS79Jx...      False
# 20  https://s3-media4.fl.yelpcdn.com/bphoto/YT2Yxs...      False
# 21  https://s3-media4.fl.yelpcdn.com/bphoto/iioU8_...      False
# 22  https://s3-media3.fl.yelpcdn.com/bphoto/hE2464...      False
# 23  https://s3-media4.fl.yelpcdn.com/bphoto/0Udtio...      False
# 24  https://s3-media3.fl.yelpcdn.com/bphoto/R25a7k...      False
# 25  https://s3-media3.fl.yelpcdn.com/bphoto/ng1F-l...      False
# 26  https://s3-media2.fl.yelpcdn.com/bphoto/rLcWH4...      False
# 27  https://s3-media2.fl.yelpcdn.com/bphoto/70DaRZ...      False
# 28  https://s3-media3.fl.yelpcdn.com/bphoto/FaO_Mk...      False
# 29  https://s3-media3.fl.yelpcdn.com/bphoto/MUmYZz...      False
# 30  https://s3-media1.fl.yelpcdn.com/bphoto/uylNus...      False
# 31  https://s3-media1.fl.yelpcdn.com/bphoto/_AFgjz...      False
# 32  https://s3-media2.fl.yelpcdn.com/bphoto/w5dDL7...      False
# 33  https://s3-media2.fl.yelpcdn.com/bphoto/iKMH15...      False
# 34  https://s3-media3.fl.yelpcdn.com/bphoto/TJoeuB...      False
# 35  https://s3-media2.fl.yelpcdn.com/bphoto/RnXjN_...      False
# 36                                                         False
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/C3PNmr...      False
# 38  https://s3-media4.fl.yelpcdn.com/bphoto/OvcnOH...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/aoohCD...      False
# 40  https://s3-media2.fl.yelpcdn.com/bphoto/fTQOMQ...      False
# 41  https://s3-media4.fl.yelpcdn.com/bphoto/w0Tz7L...      False
# 42  https://s3-media3.fl.yelpcdn.com/bphoto/i-ozRq...      False
# 43  https://s3-media3.fl.yelpcdn.com/bphoto/Vxb8xc...      False
# 44  https://s3-media3.fl.yelpcdn.com/bphoto/L4YRTZ...      False
# 45  https://s3-media1.fl.yelpcdn.com/bphoto/u_JwiK...      False
# 46  https://s3-media2.fl.yelpcdn.com/bphoto/ZXFmI6...      False
# 47  https://s3-media1.fl.yelpcdn.com/bphoto/AlPSIN...      False
# 48  https://s3-media1.fl.yelpcdn.com/bphoto/Q8xMXB...      False
# 49  https://s3-media1.fl.yelpcdn.com/bphoto/Rn7L0F...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-daily-rider-washi...            85
# 1   https://www.yelp.com/biz/rollin-cycles-bicycle...           103
# 2   https://www.yelp.com/biz/upshift-workshop-wash...             6
# 3   https://www.yelp.com/biz/city-bikes-adams-morg...           257
# 4   https://www.yelp.com/biz/bicycle-space-washing...            54
# 5   https://www.yelp.com/biz/velofix-washington?ad...            39
# 6   https://www.yelp.com/biz/contes-bike-shop-wash...            48
# 7   https://www.yelp.com/biz/the-bike-house-washin...             7
# 8   https://www.yelp.com/biz/contes-bike-shop-wash...             7
# 9   https://www.yelp.com/biz/gearin-up-bicycles-wa...            24
# 10  https://www.yelp.com/biz/district-cycle-works-...            12
# 11  https://www.yelp.com/biz/erics-mobile-workshop...             6
# 12  https://www.yelp.com/biz/nomad-bicycleworks-wa...            21
# 13  https://www.yelp.com/biz/trek-bicycle-washingt...           116
# 14  https://www.yelp.com/biz/bicycle-pro-shop-wash...            96
# 15  https://www.yelp.com/biz/bikes-and-skates-capi...            38
# 16  https://www.yelp.com/biz/city-bikes-tenleytown...            44
# 17  https://www.yelp.com/biz/big-wheel-bikes-alexa...           165
# 18  https://www.yelp.com/biz/the-old-bike-shop-arl...            87
# 19  https://www.yelp.com/biz/takoma-bicycle-takoma...            63
# 20  https://www.yelp.com/biz/griffin-cycle-bethesd...           107
# 21  https://www.yelp.com/biz/pedego-electric-bikes...            37
# 22  https://www.yelp.com/biz/riide-washington?adju...             5
# 23  https://www.yelp.com/biz/proteus-bicycles-coll...            86
# 24  https://www.yelp.com/biz/electricitybikes-wash...            20
# 25  https://www.yelp.com/biz/bike-doctor-of-waldor...            59
# 26  https://www.yelp.com/biz/bike-and-roll-dc-wash...           328
# 27  https://www.yelp.com/biz/silver-cycles-silver-...            89
# 28  https://www.yelp.com/biz/big-wheel-bikes-washi...            62
# 29  https://www.yelp.com/biz/jafe-cycling-capitol-...             5
# 30  https://www.yelp.com/biz/contes-bike-shop-arli...            67
# 31  https://www.yelp.com/biz/bicyclespace-washingt...            19
# 32  https://www.yelp.com/biz/spokes-etc-bicycles-a...           136
# 33  https://www.yelp.com/biz/rei-washington-4?adju...           119
# 34  https://www.yelp.com/biz/rapha-dc-washington?a...             7
# 35  https://www.yelp.com/biz/arrow-bicycle-hyattsv...            32
# 36  https://www.yelp.com/biz/district-cycles-washi...             6
# 37  https://www.yelp.com/biz/papillon-cycles-arlin...            93
# 38  https://www.yelp.com/biz/trek-bicycle-rockvill...            42
# 39  https://www.yelp.com/biz/probike-fc-falls-chur...            25
# 40  https://www.yelp.com/biz/contes-bike-shop-wash...            17
# 41  https://www.yelp.com/biz/wheel-nuts-bike-shop-...           135
# 42  https://www.yelp.com/biz/trek-bicycle-arlingto...           171
# 43  https://www.yelp.com/biz/v%C3%A9locity-bicycle...            65
# 44  https://www.yelp.com/biz/fleet-feet-washington...           150
# 45  https://www.yelp.com/biz/the-bicycle-place-sil...            43
# 46  https://www.yelp.com/biz/evo-cycle-works-rockv...            35
# 47  https://www.yelp.com/biz/phoenix-bikes-arlingt...            28
# 48  https://www.yelp.com/biz/big-wheel-bikes-arlin...            94
# 49  https://www.yelp.com/biz/big-wheel-bikes-bethe...            50
#
#                                            categories  rating  \
# 0   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 1   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
# 2   [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 3   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.0
# 4   [{'alias': 'bike_repair_maintenance', 'title':...     4.0
# 5   [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 6   [{'alias': 'bike_repair_maintenance', 'title':...     4.0
# 7              [{'alias': 'bikes', 'title': 'Bikes'}]     5.0
# 8   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
# 9   [{'alias': 'nonprofit', 'title': 'Community Se...     4.5
# 10  [{'alias': 'bike_repair_maintenance', 'title':...     4.5
# 11  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 12  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 13  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 14             [{'alias': 'bikes', 'title': 'Bikes'}]     3.5
# 15  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 16  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.0
# 17  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 18  [{'alias': 'bike_repair_maintenance', 'title':...     4.5
# 19  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 20  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 21  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     5.0
# 22             [{'alias': 'bikes', 'title': 'Bikes'}]     3.0
# 23  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 24             [{'alias': 'bikes', 'title': 'Bikes'}]     3.5
# 25  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 26  [{'alias': 'bikerentals', 'title': 'Bike Renta...     4.5
# 27  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 28  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
# 29  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 30  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 31  [{'alias': 'bike_repair_maintenance', 'title':...     3.0
# 32  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 33  [{'alias': 'sportgoods', 'title': 'Sporting Go...     3.0
# 34  [{'alias': 'sportswear', 'title': 'Sports Wear...     4.5
# 35  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 36  [{'alias': 'motorcyclerepair', 'title': 'Motor...     4.0
# 37  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 38  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
# 39  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 40  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.0
# 41  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     5.0
# 42  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
# 43  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 44  [{'alias': 'shoes', 'title': 'Shoe Stores'}, {...     4.5
# 45             [{'alias': 'bikes', 'title': 'Bikes'}]     4.0
# 46  [{'alias': 'bike_repair_maintenance', 'title':...     4.5
# 47             [{'alias': 'bikes', 'title': 'Bikes'}]     4.5
# 48  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.0
# 49  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
#
#                                           coordinates transactions price  \
# 0       {'latitude': 38.9004, 'longitude': -76.99815}           []    $$
# 1      {'latitude': 38.90779, 'longitude': -77.03236}           []    $$
# 2      {'latitude': 38.91409, 'longitude': -77.02021}           []   NaN
# 3      {'latitude': 38.92319, 'longitude': -77.04116}           []   $$$
# 4   {'latitude': 38.91555288609606, 'longitude': -...           []   $$$
# 5   {'latitude': 38.9104423522949, 'longitude': -7...           []   NaN
# 6   {'latitude': 38.8755404, 'longitude': -77.0006...           []    $$
# 7      {'latitude': 38.94157, 'longitude': -77.02776}           []     $
# 8      {'latitude': 38.91094, 'longitude': -77.03262}           []   NaN
# 9   {'latitude': 38.9135399, 'longitude': -77.0011...           []     $
# 10  {'latitude': 38.9095191955566, 'longitude': -7...           []   NaN
# 11  {'latitude': 38.895394132053276, 'longitude': ...           []   NaN
# 12     {'latitude': 38.93762, 'longitude': -76.99156}           []   NaN
# 13     {'latitude': 38.90526, 'longitude': -77.06836}           []   $$$
# 14   {'latitude': 38.905258, 'longitude': -77.068077}           []    $$
# 15      {'latitude': 38.87955, 'longitude': -76.8582}           []    $$
# 16     {'latitude': 38.95243, 'longitude': -77.08178}           []    $$
# 17  {'latitude': 38.8028907775879, 'longitude': -7...           []    $$
# 18  {'latitude': 38.8809493, 'longitude': -77.090245}           []    $$
# 19     {'latitude': 38.97505, 'longitude': -77.01152}           []    $$
# 20  {'latitude': 38.980987, 'longitude': -77.0997469}           []    $$
# 21  {'latitude': 38.80582466318016, 'longitude': -...           []    $$
# 22  {'latitude': 38.9220816, 'longitude': -76.9989...           []   NaN
# 23   {'latitude': 39.014772, 'longitude': -76.920292}           []    $$
# 24      {'latitude': 38.95209, 'longitude': -77.0817}           []   NaN
# 25   {'latitude': 38.622951, 'longitude': -76.904803}           []    $$
# 26   {'latitude': 38.884457, 'longitude': -77.024737}           []   NaN
# 27  {'latitude': 38.992789, 'longitude': -77.0279302}           []    $$
# 28     {'latitude': 38.90463, 'longitude': -77.06618}           []    $$
# 29  {'latitude': 38.8836288452148, 'longitude': -7...           []   NaN
# 30  {'latitude': 38.8825512965536, 'longitude': -7...           []    $$
# 31  {'latitude': 38.915561, 'longitude': -76.9819596}           []    $$
# 32     {'latitude': 38.82927, 'longitude': -77.08573}           []    $$
# 33  {'latitude': 38.9055151, 'longitude': -77.0028...           []   $$$
# 34  {'latitude': 38.9037999, 'longitude': -77.0635...           []   NaN
# 35     {'latitude': 38.95183, 'longitude': -76.94098}           []    $$
# 36     {'latitude': 38.95504, 'longitude': -77.06946}           []   NaN
# 37   {'latitude': 38.862618, 'longitude': -77.086905}           []    $$
# 38  {'latitude': 39.0624447, 'longitude': -77.1177...           []    $$
# 39     {'latitude': 38.88027, 'longitude': -77.17193}           []   NaN
# 40     {'latitude': 38.93508, 'longitude': -77.07298}           []   NaN
# 41  {'latitude': 38.8135109, 'longitude': -77.040863}           []    $$
# 42     {'latitude': 38.88939, 'longitude': -77.09165}           []   $$$
# 43      {'latitude': 38.8253, 'longitude': -77.05834}           []     $
# 44  {'latitude': 38.9214859008789, 'longitude': -7...           []    $$
# 45     {'latitude': 39.00623, 'longitude': -77.04948}           []    $$
# 46   {'latitude': 39.093622, 'longitude': -77.134568}           []   NaN
# 47  {'latitude': 38.856241, 'longitude': -77.1000176}           []     $
# 48     {'latitude': 38.89667, 'longitude': -77.09622}           []    $$
# 49  {'latitude': 38.978526358785, 'longitude': -77...           []    $$
#
#                                              location         phone  \
# 0   {'address1': '600 H St NE', 'address2': 'Ste D...  +12023960704
# 1   {'address1': '1314 14th St NW', 'address2': 'S...  +12025253712
# 2   {'address1': '', 'address2': '', 'address3': N...
# 3   {'address1': '2501 Champlain St NW', 'address2...  +12022651564
# 4   {'address1': '1512 Okie St NE', 'address2': ''...  +12028539390
# 5   {'address1': None, 'address2': None, 'address3...  +18558356349
# 6   {'address1': '1331 4th St SE', 'address2': 'St...  +12025589866
# 7   {'address1': '1240 Upshur St NW', 'address2': ...
# 8   {'address1': '1412 Q St NW', 'address2': '', '...  +12023872453
# 9   {'address1': '314 Randolph Pl NE', 'address2':...  +12027805174
# 10  {'address1': '2603 P St NW', 'address2': '', '...  +12026433040
# 11  {'address1': '417 18th St NE', 'address2': Non...  +12023021925
# 12  {'address1': 'Michigan Ave NE', 'address2': No...  +12023225020
# 13  {'address1': '3411 M St NW', 'address2': '', '...  +12029653601
# 14  {'address1': '3403 M St NW', 'address2': '', '...  +12023370311
# 15  {'address1': '712 Ritchie Rd', 'address2': Non...  +13013332453
# 16  {'address1': '4810 Wisconsin Ave NW', 'address...  +12025580055
# 17  {'address1': '2 Prince St', 'address2': '', 'a...  +17037392300
# 18  {'address1': '2647 N Pershing Dr', 'address2':...  +15713121730
# 19  {'address1': '7030 Carroll Ave', 'address2': '...  +13012700202
# 20  {'address1': '4933 Bethesda Ave', 'address2': ...  +13016566188
# 21  {'address1': '210 N Lee St', 'address2': 'Unit...  +15713125168
# 22  {'address1': '524 Rhode Island Ave NE', 'addre...  +12028001549
# 23  {'address1': '9827 Rhode Island Ave', 'address...  +13014412928
# 24  {'address1': '4800 Wisconsin Ave Nw B', 'addre...  +12025580055
# 25  {'address1': '3200 Leonardtown Rd', 'address2'...  +13019329980
# 26  {'address1': '955 L'Enfant Plz SW', 'address2'...  +12028422453
# 27  {'address1': '8307 Dixon Ave', 'address2': '',...  +13015851889
# 28  {'address1': '1034 33rd St NW', 'address2': ''...  +12023370254
# 29  {'address1': None, 'address2': None, 'address3...  +12029534210
# 30  {'address1': '3449 Wilson Blvd', 'address2': '...  +15718003126
# 31  {'address1': '1512 Okie St NE', 'address2': ''...  +12028539390
# 32  {'address1': '1545 N Quaker Ln', 'address2': '...  +17038202200
# 33  {'address1': '201 M St NE', 'address2': '', 'a...  +12025432040
# 34  {'address1': '3210 Grace St', 'address2': None...  +12027331692
# 35  {'address1': '5108 Baltimore Ave', 'address2':...  +13015319250
# 36  {'address1': '5001 Connecticut Ave NW', 'addre...  +12024926649
# 37  {'address1': '2805 Columbia Pike', 'address2':...  +17039209494
# 38  {'address1': '5750 Fishers Ln', 'address2': 'S...  +13014240990
# 39  {'address1': '116 E Fairfax St', 'address2': N...  +17038541427
# 40  {'address1': '3410 Wisconsin Ave NW', 'address...  +12023910804
# 41  {'address1': '302 Montgomery St', 'address2': ...  +17035485116
# 42  {'address1': '2731 Wilson Blvd', 'address2': '...  +17033120007
# 43  {'address1': '2111 Mt Vernon Ave', 'address2':...  +17035491108
# 44  {'address1': '1841 Columbia Rd NW', 'address2'...  +12023873888
# 45  {'address1': '9168 Brookville Rd', 'address2':...  +13015886160
# 46  {'address1': '1172 Taft St', 'address2': None,...  +12406174053
# 47  {'address1': '909 S Dinwiddie St', 'address2':...  +17035757762
# 48  {'address1': '3119 Lee Hwy', 'address2': '', '...  +17035221110
# 49  {'address1': '6917 Arlington Rd', 'address2': ...  +13016520192
#
#      display_phone      distance
# 0   (202) 396-0704   3097.866378
# 1   (202) 525-3712    413.209757
# 2                    1008.799142
# 3   (202) 265-1564   1607.917071
# 4   (202) 853-9390   4238.354077
# 5   (855) 835-6349   1008.799142
# 6   (202) 558-9866   4849.692728
# 7                    3376.411706
# 8   (202) 387-2453    173.239182
# 9   (202) 780-5174   2558.729650
# 10  (202) 643-3040   2116.509941
# 11  (202) 302-1925   4822.856421
# 12  (202) 322-5020   4320.584531
# 13  (202) 965-3601   3331.086453
# 14  (202) 337-0311   3307.581751
# 15  (301) 333-2453  15342.366033
# 16  (202) 558-0055   6370.388234
# 17  (703) 739-2300  12081.532152
# 18  (571) 312-1730   6163.849882
# 19  (301) 270-0202   7279.667522
# 20  (301) 656-6188   9786.280545
# 21  (571) 312-5168  11764.370522
# 22  (202) 800-1549   2992.073022
# 23  (301) 441-2928  14947.159536
# 24  (202) 558-0055   6332.531613
# 25  (301) 932-9980  33868.915456
# 26  (202) 842-2453   3027.491582
# 27  (301) 585-1889   9064.896292
# 28  (202) 337-0254   3162.718900
# 29  (202) 953-4210  10355.146808
# 30  (571) 800-3126   6923.915476
# 31  (202) 853-9390   4238.454751
# 32  (703) 820-2200  10243.390543
# 33  (202) 543-2040   2518.087496
# 34  (202) 733-1692   2963.834217
# 35  (301) 531-9250   8986.025301
# 36  (202) 492-6649   5917.963112
# 37  (703) 920-9494   7280.853068
# 38  (301) 424-0990  18411.174868
# 39  (703) 854-1427  12683.669693
# 40  (202) 391-0804   4517.968264
# 41  (703) 548-5116  10913.802794
# 42  (703) 312-0007   5806.494485
# 43  (703) 549-1108   9853.620265
# 44  (202) 387-3888   1621.329046
# 45  (301) 588-6160  10680.945421
# 46  (240) 617-4053  22173.976275
# 47  (703) 575-7762   8575.241096
# 48  (703) 522-1110   5918.185793
# 49  (301) 652-0192   9505.516361

# %%
data_df.shape
# Out:
# (50, 16)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             50 non-null     object
#  1   alias          50 non-null     object
#  2   name           50 non-null     object
#  3   image_url      50 non-null     object
#  4   is_closed      50 non-null     bool
#  5   url            50 non-null     object
#  6   review_count   50 non-null     int64
#  7   categories     50 non-null     object
#  8   rating         50 non-null     float64
#  9   coordinates    50 non-null     object
#  10  transactions   50 non-null     object
#  11  price          35 non-null     object
#  12  location       50 non-null     object
#  13  phone          50 non-null     object
#  14  display_phone  50 non-null     object
#  15  distance       50 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 6.0+ KB

# %%
data_df.describe()
# Out:
#        review_count     rating      distance
# count     50.000000  50.000000     50.000000
# mean      68.200000   4.140000   7250.109487
# std       65.000785   0.662709   6097.093524
# min        5.000000   3.000000    173.239182
# 25%       21.750000   3.500000   3114.079509
# 50%       49.000000   4.500000   5918.074453
# 75%       93.750000   4.500000   9836.785335
# max      328.000000   5.000000  33868.915456

# %%
pd.DataFrame(data_df.groupby('name'))
# Out:
#                                           0  \
# 0                             Arrow Bicycle
# 1                          Bicycle Pro Shop
# 2                             Bicycle Space
# 3                 BicycleSPACE - Washington
# 4                           Big Wheel Bikes
# 5                          Bike And Roll DC
# 6                    Bike Doctor of Waldorf
# 7                            Bikes & Skates
# 8                 City Bikes - Adams Morgan
# 9                     City Bikes Tenleytown
# 10                        Conte's Bike Shop
# 11                     District Cycle Works
# 12                          District Cycles
# 13                         ElectriCityBikes
# 14                   Eric's Mobile Workshop
# 15                          Evo Cycle Works
# 16                               Fleet Feet
# 17                      Gearin' Up Bicycles
# 18                            Griffin Cycle
# 19                             Jafe Cycling
# 20                       Nomad Bicycleworks
# 21                          Papillon Cycles
# 22         Pedego Electric Bikes Alexandria
# 23                            Phoenix Bikes
# 24                               ProBike FC
# 25                         Proteus Bicycles
# 26                                      REI
# 27                                 Rapha DC
# 28                                    Riide
# 29               Rollin Cycles Bicycle Shop
# 30                            Silver Cycles
# 31                     Spokes Etc. Bicycles
# 32                           Takoma Bicycle
# 33                        The Bicycle Place
# 34                           The Bike House
# 35                          The Daily Rider
# 36                        The Old Bike Shop
# 37         Trek Bicycle Arlington Clarendon
# 38                   Trek Bicycle Rockville
# 39  Trek Bicycle Washington D.C. Georgetown
# 40                         Upshift Workshop
# 41             VéloCity Bicycle Cooperative
# 42                     Wheel Nuts Bike Shop
# 43                                  velofix
#
#                                                     1
# 0                           id                    ...
# 1                           id                    ...
# 2                          id                     ...
# 3                           id                    ...
# 4                           id                    ...
# 5                           id                    ...
# 6                           id                    ...
# 7                           id                    ...
# 8                          id                     ...
# 9                           id                    ...
# 10                          id                    ...
# 11                          id                    ...
# 12                          id                    ...
# 13                          id                    ...
# 14                          id                    ...
# 15                          id                    ...
# 16                          id                  al...
# 17                         id                     ...
# 18                          id                    ...
# 19                          id                    ...
# 20                          id                    ...
# 21                          id                    ...
# 22                          id                    ...
# 23                          id                    ...
# 24                          id                    ...
# 25                          id                    ...
# 26                          id             alias n...
# 27                          id                alia...
# 28                          id             alias  ...
# 29                         id                     ...
# 30                          id                    ...
# 31                          id                    ...
# 32                          id                    ...
# 33                          id                    ...
# 34                         id                     ...
# 35                         id                     ...
# 36                          id                    ...
# 37                          id                    ...
# 38                          id                    ...
# 39                          id                    ...
# 40                         id                     ...
# 41                          id                    ...
# 42                          id                    ...
# 43                         id               alias ...

# %% [markdown]
# - Write a function to parse the API response so that you can easily insert the data in to the DB

# %%
#data = results.json()

# %%
#business = data['businesses'][0]

# %%
#biz_info = (business['id'], business['name'], business['is_closed'], business['review_count'], business['rating'], business['location']['zip_code'])

# %%
#biz_info

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    results = results.json()['businesses']
    parsed_data = []
    for business in results:
        if 'price' not in business:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], 'NaN',
                business['location']['zip_code'])
            parsed_data.append(biz_info)
        else:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], business['price'],
                business['location']['zip_code'])
            parsed_data.append(biz_info)
    return parsed_data

# %%
parsed_results = parse_results(results)
parsed_results
# Out:
# [('Dn04j5YabUDWS7nUbpfZGg', 'The Daily Rider', False, 85, 4.5, '$$', '20002'),
#  ('astpI6075yghzNk2XFiybA',
#   'Rollin Cycles Bicycle Shop',
#   False,
#   103,
#   3.5,
#   '$$',
#   '20005'),
#  ('F0fMNrrBU3OKMdwfCL5mRA', 'Upshift Workshop', False, 6, 5.0, 'NaN', '20001'),
#  ('YvDCWE1O_Q6JLMiKHb4tGQ',
#   'City Bikes - Adams Morgan',
#   False,
#   257,
#   3.0,
#   '$$$',
#   '20009'),
#  ('ATpgglOwwQUno5QhAEXc2g', 'Bicycle Space', False, 54, 4.0, '$$$', '20002'),
#  ('OxnwyBMJN43a_5UHL3UHWQ', 'velofix', False, 39, 5.0, 'NaN', '20001'),
#  ('3tbIAR6xTrgSRO3m2da0Vg',
#   "Conte's Bike Shop",
#   False,
#   48,
#   4.0,
#   '$$',
#   '20003'),
#  ('2q9eO68Q-PDAUUfdx-zvqw', 'The Bike House', False, 7, 5.0, '$', '20542'),
#  ('gmXiBdjkKVTGM-4mU8Sepw',
#   "Conte's Bike Shop",
#   False,
#   7,
#   3.5,
#   'NaN',
#   '20009'),
#  ('yGJ5jSQPSqp8i5rojSJnHQ',
#   "Gearin' Up Bicycles",
#   False,
#   24,
#   4.5,
#   '$',
#   '20002'),
#  ('NBsk50CXW85OFAkxnOao8Q',
#   'District Cycle Works',
#   False,
#   12,
#   4.5,
#   'NaN',
#   '20007'),
#  ('obfGllLjyMkQ1iA_HtT1bQ',
#   "Eric's Mobile Workshop",
#   False,
#   6,
#   5.0,
#   'NaN',
#   '20002'),
#  ('8eVGxeIopFn5hUX_YVkbGQ',
#   'Nomad Bicycleworks',
#   False,
#   21,
#   5.0,
#   'NaN',
#   '20017'),
#  ('R2HBjZ0HYWIRquHMVBNA_w',
#   'Trek Bicycle Washington D.C. Georgetown',
#   False,
#   116,
#   4.0,
#   '$$$',
#   '20007'),
#  ('8mwlRyZ6FH2VW10tlHE2Qg', 'Bicycle Pro Shop', False, 96, 3.5, '$$', '20007'),
#  ('2NvqroYky8n4wO6agru4Kw', 'Bikes & Skates', False, 38, 4.0, '$$', '20743'),
#  ('Wqmx9LXrKzAUGeTZRV3XZg',
#   'City Bikes Tenleytown',
#   False,
#   44,
#   3.0,
#   '$$',
#   '20016'),
#  ('Nnfhnuqv2WTeHRs_mDFPRA', 'Big Wheel Bikes', False, 165, 4.5, '$$', '22314'),
#  ('jQoYuCkGdeGNRfif4JlYDw',
#   'The Old Bike Shop',
#   False,
#   87,
#   4.5,
#   '$$',
#   '22201'),
#  ('dEUQ7Of8leYhaRF12qTswQ', 'Takoma Bicycle', False, 63, 4.5, '$$', '20912'),
#  ('-zIt1sAhZpndaiWjMFVGcA', 'Griffin Cycle', False, 107, 4.5, '$$', '20814'),
#  ('uq9j3G6MJtd_Mv5rfF5oRQ',
#   'Pedego Electric Bikes Alexandria',
#   False,
#   37,
#   5.0,
#   '$$',
#   '22314'),
#  ('Sb_3F7bcGYLGjUssQfiP6w', 'Riide', False, 5, 3.0, 'NaN', '20001'),
#  ('CZSLn0w5xUESdprbfINn8w', 'Proteus Bicycles', False, 86, 4.5, '$$', '20740'),
#  ('p9U34BqsfvgY2zKTW6fFkg',
#   'ElectriCityBikes',
#   False,
#   20,
#   3.5,
#   'NaN',
#   '20016'),
#  ('iILgX1Q8tc29Onj8OgdKOA',
#   'Bike Doctor of Waldorf',
#   False,
#   59,
#   4.5,
#   '$$',
#   '20601'),
#  ('MnV2zaZSXToe-vpkTccZ4Q',
#   'Bike And Roll DC',
#   False,
#   328,
#   4.5,
#   'NaN',
#   '20024'),
#  ('cU4Dg9ltf53aFoLBh8Ndkw', 'Silver Cycles', False, 89, 4.0, '$$', '20910'),
#  ('SVk-4xwL9tA9TSB0ZnWFBA', 'Big Wheel Bikes', False, 62, 3.5, '$$', '20007'),
#  ('AjIOtN_0SlyY2dgVuBbwhg', 'Jafe Cycling', False, 5, 5.0, 'NaN', '20743'),
#  ('DPUPnCnPwCdcFl6U7nBNsw',
#   "Conte's Bike Shop",
#   False,
#   67,
#   4.5,
#   '$$',
#   '22201'),
#  ('4wh6LsjL0Cki3IfJbSSzrA',
#   'BicycleSPACE - Washington',
#   False,
#   19,
#   3.0,
#   '$$',
#   '20002'),
#  ('ky_3ss5asDpYqb8L1x3P-Q',
#   'Spokes Etc. Bicycles',
#   False,
#   136,
#   4.5,
#   '$$',
#   '22302'),
#  ('RfsW8djTUV8TfDHy9TxfUw', 'REI', False, 119, 3.0, '$$$', '20002'),
#  ('WXuilvVlx0MzBqX1e6GO6A', 'Rapha DC', False, 7, 4.5, 'NaN', '20007'),
#  ('xSzKaAq6vgZZDn3S5-V9Hw', 'Arrow Bicycle', False, 32, 4.5, '$$', '20781'),
#  ('q-pvnWBgielD--bA81hLFQ', 'District Cycles', False, 6, 4.0, 'NaN', '20008'),
#  ('wdQepvuFBpPKJ1R6titiNA', 'Papillon Cycles', False, 93, 4.5, '$$', '22204'),
#  ('NM9NmHZ_KbNsmrfrP3Whvg',
#   'Trek Bicycle Rockville',
#   False,
#   42,
#   3.5,
#   '$$',
#   '20852'),
#  ('1q-0mrzsr1EIF5U0aTPFXQ', 'ProBike FC', False, 25, 5.0, 'NaN', '22046'),
#  ('Z97inykgHENrsBTg1S__wA',
#   "Conte's Bike Shop",
#   False,
#   17,
#   3.0,
#   'NaN',
#   '20016'),
#  ('YvguUf5tL6HDElwIAhjZ4Q',
#   'Wheel Nuts Bike Shop',
#   False,
#   135,
#   5.0,
#   '$$',
#   '22314'),
#  ('CmJmSF3Cw0lxuxwusJV8_Q',
#   'Trek Bicycle Arlington Clarendon',
#   False,
#   171,
#   3.5,
#   '$$$',
#   '22201'),
#  ('xTrJ9Q5tNAAkj5p9Du7yRw',
#   'VéloCity Bicycle Cooperative',
#   False,
#   65,
#   4.0,
#   '$',
#   '22301'),
#  ('AsOcjvsQQfADGDft5LmzpQ', 'Fleet Feet', False, 150, 4.5, '$$', '20009'),
#  ('3mFZjswCTJ2X4MRBNRdSjA',
#   'The Bicycle Place',
#   False,
#   43,
#   4.0,
#   '$$',
#   '20910'),
#  ('htdy8C1Rdz9baITZemFqgg', 'Evo Cycle Works', False, 35, 4.5, 'NaN', '20850'),
#  ('wuFuQt1lI0kvy8ZaCie8WQ', 'Phoenix Bikes', False, 28, 4.5, '$', '22204'),
#  ('0KQG1qvOX8w7lPWa61w8OQ', 'Big Wheel Bikes', False, 94, 3.0, '$$', '22201'),
#  ('d50OtT7Y4N5l3OeBtRwIdA', 'Big Wheel Bikes', False, 50, 3.5, '$$', '20814')]

# %%
bike_df = pd.DataFrame(parsed_results, columns = ('ID', 'Name', 'Is_Closed',
                                           'Review_Count', 'Rating', 'Price',
                                           'Zip_Code'))
bike_df
# Out:
#                         ID                                     Name  \
# 0   Dn04j5YabUDWS7nUbpfZGg                          The Daily Rider
# 1   astpI6075yghzNk2XFiybA               Rollin Cycles Bicycle Shop
# 2   F0fMNrrBU3OKMdwfCL5mRA                         Upshift Workshop
# 3   YvDCWE1O_Q6JLMiKHb4tGQ                City Bikes - Adams Morgan
# 4   ATpgglOwwQUno5QhAEXc2g                            Bicycle Space
# 5   OxnwyBMJN43a_5UHL3UHWQ                                  velofix
# 6   3tbIAR6xTrgSRO3m2da0Vg                        Conte's Bike Shop
# 7   2q9eO68Q-PDAUUfdx-zvqw                           The Bike House
# 8   gmXiBdjkKVTGM-4mU8Sepw                        Conte's Bike Shop
# 9   yGJ5jSQPSqp8i5rojSJnHQ                      Gearin' Up Bicycles
# 10  NBsk50CXW85OFAkxnOao8Q                     District Cycle Works
# 11  obfGllLjyMkQ1iA_HtT1bQ                   Eric's Mobile Workshop
# 12  8eVGxeIopFn5hUX_YVkbGQ                       Nomad Bicycleworks
# 13  R2HBjZ0HYWIRquHMVBNA_w  Trek Bicycle Washington D.C. Georgetown
# 14  8mwlRyZ6FH2VW10tlHE2Qg                         Bicycle Pro Shop
# 15  2NvqroYky8n4wO6agru4Kw                           Bikes & Skates
# 16  Wqmx9LXrKzAUGeTZRV3XZg                    City Bikes Tenleytown
# 17  Nnfhnuqv2WTeHRs_mDFPRA                          Big Wheel Bikes
# 18  jQoYuCkGdeGNRfif4JlYDw                        The Old Bike Shop
# 19  dEUQ7Of8leYhaRF12qTswQ                           Takoma Bicycle
# 20  -zIt1sAhZpndaiWjMFVGcA                            Griffin Cycle
# 21  uq9j3G6MJtd_Mv5rfF5oRQ         Pedego Electric Bikes Alexandria
# 22  Sb_3F7bcGYLGjUssQfiP6w                                    Riide
# 23  CZSLn0w5xUESdprbfINn8w                         Proteus Bicycles
# 24  p9U34BqsfvgY2zKTW6fFkg                         ElectriCityBikes
# 25  iILgX1Q8tc29Onj8OgdKOA                   Bike Doctor of Waldorf
# 26  MnV2zaZSXToe-vpkTccZ4Q                         Bike And Roll DC
# 27  cU4Dg9ltf53aFoLBh8Ndkw                            Silver Cycles
# 28  SVk-4xwL9tA9TSB0ZnWFBA                          Big Wheel Bikes
# 29  AjIOtN_0SlyY2dgVuBbwhg                             Jafe Cycling
# 30  DPUPnCnPwCdcFl6U7nBNsw                        Conte's Bike Shop
# 31  4wh6LsjL0Cki3IfJbSSzrA                BicycleSPACE - Washington
# 32  ky_3ss5asDpYqb8L1x3P-Q                     Spokes Etc. Bicycles
# 33  RfsW8djTUV8TfDHy9TxfUw                                      REI
# 34  WXuilvVlx0MzBqX1e6GO6A                                 Rapha DC
# 35  xSzKaAq6vgZZDn3S5-V9Hw                            Arrow Bicycle
# 36  q-pvnWBgielD--bA81hLFQ                          District Cycles
# 37  wdQepvuFBpPKJ1R6titiNA                          Papillon Cycles
# 38  NM9NmHZ_KbNsmrfrP3Whvg                   Trek Bicycle Rockville
# 39  1q-0mrzsr1EIF5U0aTPFXQ                               ProBike FC
# 40  Z97inykgHENrsBTg1S__wA                        Conte's Bike Shop
# 41  YvguUf5tL6HDElwIAhjZ4Q                     Wheel Nuts Bike Shop
# 42  CmJmSF3Cw0lxuxwusJV8_Q         Trek Bicycle Arlington Clarendon
# 43  xTrJ9Q5tNAAkj5p9Du7yRw             VéloCity Bicycle Cooperative
# 44  AsOcjvsQQfADGDft5LmzpQ                               Fleet Feet
# 45  3mFZjswCTJ2X4MRBNRdSjA                        The Bicycle Place
# 46  htdy8C1Rdz9baITZemFqgg                          Evo Cycle Works
# 47  wuFuQt1lI0kvy8ZaCie8WQ                            Phoenix Bikes
# 48  0KQG1qvOX8w7lPWa61w8OQ                          Big Wheel Bikes
# 49  d50OtT7Y4N5l3OeBtRwIdA                          Big Wheel Bikes
#
#     Is_Closed  Review_Count  Rating Price Zip_Code
# 0       False            85     4.5    $$    20002
# 1       False           103     3.5    $$    20005
# 2       False             6     5.0   NaN    20001
# 3       False           257     3.0   $$$    20009
# 4       False            54     4.0   $$$    20002
# 5       False            39     5.0   NaN    20001
# 6       False            48     4.0    $$    20003
# 7       False             7     5.0     $    20542
# 8       False             7     3.5   NaN    20009
# 9       False            24     4.5     $    20002
# 10      False            12     4.5   NaN    20007
# 11      False             6     5.0   NaN    20002
# 12      False            21     5.0   NaN    20017
# 13      False           116     4.0   $$$    20007
# 14      False            96     3.5    $$    20007
# 15      False            38     4.0    $$    20743
# 16      False            44     3.0    $$    20016
# 17      False           165     4.5    $$    22314
# 18      False            87     4.5    $$    22201
# 19      False            63     4.5    $$    20912
# 20      False           107     4.5    $$    20814
# 21      False            37     5.0    $$    22314
# 22      False             5     3.0   NaN    20001
# 23      False            86     4.5    $$    20740
# 24      False            20     3.5   NaN    20016
# 25      False            59     4.5    $$    20601
# 26      False           328     4.5   NaN    20024
# 27      False            89     4.0    $$    20910
# 28      False            62     3.5    $$    20007
# 29      False             5     5.0   NaN    20743
# 30      False            67     4.5    $$    22201
# 31      False            19     3.0    $$    20002
# 32      False           136     4.5    $$    22302
# 33      False           119     3.0   $$$    20002
# 34      False             7     4.5   NaN    20007
# 35      False            32     4.5    $$    20781
# 36      False             6     4.0   NaN    20008
# 37      False            93     4.5    $$    22204
# 38      False            42     3.5    $$    20852
# 39      False            25     5.0   NaN    22046
# 40      False            17     3.0   NaN    20016
# 41      False           135     5.0    $$    22314
# 42      False           171     3.5   $$$    22201
# 43      False            65     4.0     $    22301
# 44      False           150     4.5    $$    20009
# 45      False            43     4.0    $$    20910
# 46      False            35     4.5   NaN    20850
# 47      False            28     4.5     $    22204
# 48      False            94     3.0    $$    22201
# 49      False            50     3.5    $$    20814

# %% [markdown]
# - Write a function to take your parsed data and add it to the csv file where you will store all of your results.

# %%
bike_df.to_csv('C:/Users/acumu/Documents/Flatiron/Phase_1_Project/bikedata.csv', index = False, encoding='utf-8')

# %%
api_key = creds['key']
term = 'bike shop'
location = 'Washington DC'
SEARCH_LIMIT = 50
url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'offset': 50 
    }

# %%
def yelp_call(url_params, api_key):
    # your code to make the yelp call
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer ' + api_key}
    
    data = requests.get(url, headers = headers, params = url_params)
    return data

# %%
results2 = yelp_call(url_params, api_key)

# %%
results2.json()
# Out:
# {'businesses': [{'id': 'aCcwo1rqNDc2EdNbrGQYlw',
#    'alias': 'college-park-bicycles-college-park',
#    'name': 'College Park Bicycles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3QaD5QK4256lr3voRyFgTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/college-park-bicycles-college-park?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 33,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 38.97857, 'longitude': -76.9376},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7301 Baltimore Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'College Park',
#     'zip_code': '20740',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['7301 Baltimore Ave', 'College Park, MD 20740']},
#    'phone': '+13018642211',
#    'display_phone': '(301) 864-2211',
#    'distance': 10988.295162983777},
#   {'id': 'aes6SOPlGBSi4FoHknWbUQ',
#    'alias': 'east-potomac-golf-course-washington-2',
#    'name': 'East Potomac Golf Course',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L08dmj0rYlIVtuyoh7oQZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/east-potomac-golf-course-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 114,
#    'categories': [{'alias': 'golf', 'title': 'Golf'},
#     {'alias': 'mini_golf', 'title': 'Mini Golf'},
#     {'alias': 'golfequipment', 'title': 'Golf Equipment'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.874701, 'longitude': -77.027491},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '972 Ohio Dr SW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20024',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['972 Ohio Dr SW', 'Washington, DC 20024']},
#    'phone': '+12025547660',
#    'display_phone': '(202) 554-7660',
#    'distance': 4078.018624946606},
#   {'id': 'q_CSikkPgszHI5LvEWU6HQ',
#    'alias': 'fat-tire-tours-washington-2',
#    'name': 'Fat Tire Tours',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ul2-QjJDOizwlIVpl1G0Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fat-tire-tours-washington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 30,
#    'categories': [{'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'biketours', 'title': 'Bike tours'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.8966086, 'longitude': -77.0502508},
#    'transactions': [],
#    'location': {'address1': '502 23rd St NW',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20037',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['502 23rd St NW', 'Washington, DC 20037']},
#    'phone': '+18777348687',
#    'display_phone': '(877) 734-8687',
#    'distance': 2355.0172375727343},
#   {'id': 'OG5nM2il0cp0MaK6c9AJAw',
#    'alias': 'spokes-etc-bicycles-arlington',
#    'name': 'Spokes Etc. Bicycles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0fAT5HieP9QtQVNrDq7dgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spokes-etc-bicycles-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 19,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'sportswear', 'title': 'Sports Wear'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.87966, 'longitude': -77.10725},
#    'transactions': [],
#    'location': {'address1': '3924 Wilson Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Arlington',
#     'zip_code': '22203',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3924 Wilson Blvd', 'Arlington, VA 22203']},
#    'phone': '+17032489600',
#    'display_phone': '(703) 248-9600',
#    'distance': 7518.980045558421},
#   {'id': 'r_3e6XcQN2Hb_h6U_qiSwQ',
#    'alias': 'handy-bikes-alexandria-2',
#    'name': 'Handy Bikes',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Rp3CtcvzKawzHY99lxXRCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/handy-bikes-alexandria-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 46,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.80741, 'longitude': -77.0972559},
#    'transactions': [],
#    'location': {'address1': '3800 Wheeler Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Alexandria',
#     'zip_code': '22304',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3800 Wheeler Ave', 'Alexandria, VA 22304']},
#    'phone': '+17035987795',
#    'display_phone': '(703) 598-7795',
#    'distance': 12911.356410497156},
#   {'id': 'UiAA5CKvEcni6IF3xoWZjw',
#    'alias': 'cycles-of-silver-spring-silver-spring',
#    'name': 'Cycles of Silver Spring',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lo2Rb1XxZzcoeZlsV333_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cycles-of-silver-spring-silver-spring?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 30,
#    'categories': [{'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'},
#     {'alias': 'motorcycledealers', 'title': 'Motorcycle Dealers'},
#     {'alias': 'motorcyclinggear', 'title': 'Motorcycle Gear'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.0017077714102,
#     'longitude': -77.054071934953},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '8910 Brookville Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Silver Spring',
#     'zip_code': '20910',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['8910 Brookville Rd', 'Silver Spring, MD 20910']},
#    'phone': '+13015892453',
#    'display_phone': '(301) 589-2453',
#    'distance': 10255.72402656066},
#   {'id': '5UZFR7qk81jwYF3n_ZwJEA',
#    'alias': 'bikenetic-full-service-bicycle-shop-falls-church',
#    'name': 'Bikenetic Full Service Bicycle Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x9thH2iTHiFkYnyn1FVIyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bikenetic-full-service-bicycle-shop-falls-church?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 95,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.887083, 'longitude': -77.166158},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '201 W Jefferson St',
#     'address2': '',
#     'address3': '',
#     'city': 'Falls Church',
#     'zip_code': '22046',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['201 W Jefferson St', 'Falls Church, VA 22046']},
#    'phone': '+17035347433',
#    'display_phone': '(703) 534-7433',
#    'distance': 12032.45383935261},
#   {'id': 'EvLmGhOsWKkXGLGhGKVM3Q',
#    'alias': 'clinton-cycles-camp-springs-2',
#    'name': 'Clinton Cycles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1xH4G9p-Swsignj1qMkK8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/clinton-cycles-camp-springs-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 15,
#    'categories': [{'alias': 'motorcycledealers',
#      'title': 'Motorcycle Dealers'},
#     {'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'},
#     {'alias': 'motorcyclinggear', 'title': 'Motorcycle Gear'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 38.797, 'longitude': -76.90156},
#    'transactions': [],
#    'location': {'address1': '6709 Old Branch Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Camp Springs',
#     'zip_code': '20748',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['6709 Old Branch Ave', 'Camp Springs, MD 20748']},
#    'phone': '+13014495900',
#    'display_phone': '(301) 449-5900',
#    'distance': 16923.794224259087},
#   {'id': 'iIJqWC2hEsxG8NUUa9bvtA',
#    'alias': 'mittens-pop-up-bike-shop-washington',
#    'name': 'Mittens Pop Up Bike Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6MQZWoUiCrJdL_EZ5eq6vQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mittens-pop-up-bike-shop-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 4,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.91409, 'longitude': -77.02021},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'Washington, DC',
#     'zip_code': '20001',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['Washington, DC 20001']},
#    'phone': '+12026976790',
#    'display_phone': '(202) 697-6790',
#    'distance': 1008.7991422520444},
#   {'id': 'ZNNwWunapph3PAWhq4OwDg',
#    'alias': 'a-and-j-cycle-performance-upper-marlboro',
#    'name': 'A & J Cycle Performance',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-and-j-cycle-performance-upper-marlboro?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 8,
#    'categories': [{'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8335999, 'longitude': -76.86286},
#    'transactions': [],
#    'location': {'address1': '8411 Old Marlboro Pike',
#     'address2': 'Bldg 23',
#     'address3': None,
#     'city': 'Upper Marlboro',
#     'zip_code': '20772',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['8411 Old Marlboro Pike',
#      'Bldg 23',
#      'Upper Marlboro, MD 20772']},
#    'phone': '+13015164144',
#    'display_phone': '(301) 516-4144',
#    'distance': 16912.389525960778},
#   {'id': 'Jy6gV4N_57LR8bu67cQzrA',
#    'alias': 'crossroads-cycle-falls-church',
#    'name': 'Crossroads Cycle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p2Vum8Qk4MSiOYjR4BYvbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crossroads-cycle-falls-church?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 37,
#    'categories': [{'alias': 'motorcycledealers',
#      'title': 'Motorcycle Dealers'},
#     {'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8489875793457,
#     'longitude': -77.1279907226562},
#    'transactions': [],
#    'location': {'address1': '5715 Leesburg Pike',
#     'address2': '',
#     'address3': '',
#     'city': 'Falls Church',
#     'zip_code': '22041',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['5715 Leesburg Pike', 'Falls Church, VA 22041']},
#    'phone': '+17038203711',
#    'display_phone': '(703) 820-3711',
#    'distance': 10906.28056920008},
#   {'id': 'vy2H6Xf55NhC0938QIzA4Q',
#    'alias': 'spokes-etc-bicycles-alexandria',
#    'name': 'Spokes Etc. Bicycles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kfn_cxJ_5V7b4iEhBASFqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spokes-etc-bicycles-alexandria?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 48,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'outdoorgear', 'title': 'Outdoor Gear'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.775441, 'longitude': -77.059321},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1506 Belle View Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22307',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['1506 Belle View Blvd', 'Alexandria, VA 22307']},
#    'phone': '+17037658005',
#    'display_phone': '(703) 765-8005',
#    'distance': 15307.656845965243},
#   {'id': 'fA06wgVa8CwCZOWTL8cw3A',
#    'alias': 'unlimited-biking-washington',
#    'name': 'Unlimited Biking',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T8747keMmoJa1TCw4hMqYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/unlimited-biking-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 3,
#    'categories': [{'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'biketours', 'title': 'Bike tours'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.884514, 'longitude': -77.025102},
#    'transactions': [],
#    'location': {'address1': "955 L'Enfant Plz SW",
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20024',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ["955 L'Enfant Plz SW", 'Washington, DC 20024']},
#    'phone': '+12028422453',
#    'display_phone': '(202) 842-2453',
#    'distance': 3018.318749175203},
#   {'id': 'rLBUUBSBArIy9hxJncaRUg',
#    'alias': 'hybrid-pedals-arlington-2',
#    'name': 'Hybrid Pedals',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/azRZKRFqcHhNPa3K5rJPNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hybrid-pedals-arlington-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 24,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.8826293945312,
#     'longitude': -77.1001129150391},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '822 N Kenmore St',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['822 N Kenmore St', 'Arlington, VA 22201']},
#    'phone': '+15712381729',
#    'display_phone': '(571) 238-1729',
#    'distance': 6814.04466473661},
#   {'id': 'aowukYOxbvpUuNKvxMeOWA',
#    'alias': 'contes-bike-shop-falls-church',
#    'name': "Conte's Bike Shop",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Fx-4X_EEQqu18PPZf_ntjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/contes-bike-shop-falls-church?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 37,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8937204, 'longitude': -77.1873109},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1118 W Broad St',
#     'address2': None,
#     'address3': '',
#     'city': 'Falls Church',
#     'zip_code': '22046',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['1118 W Broad St', 'Falls Church, VA 22046']},
#    'phone': '+17036390343',
#    'display_phone': '(703) 639-0343',
#    'distance': 13697.412524027077},
#   {'id': 'EgGkiQUAEd8iUReQfJyFZg',
#    'alias': 'pacers-running-washington-3',
#    'name': 'Pacers Running',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hyl4_cQqjeDsH9JSQ0-Dkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pacers-running-washington-3?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 16,
#    'categories': [{'alias': 'shoes', 'title': 'Shoe Stores'},
#     {'alias': 'sportgoods', 'title': 'Sporting Goods'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.875186, 'longitude': -77.001304},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '300 Tingey St SE',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20003',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['300 Tingey St SE', 'Washington, DC 20003']},
#    'phone': '+12025541216',
#    'display_phone': '(202) 554-1216',
#    'distance': 4743.7946872347375},
#   {'id': 'oYElueOSr_rUkgisyw7Gnw',
#    'alias': 'georgetown-running-company-washington',
#    'name': 'Georgetown Running Company',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4TK3z7hCPNpvPKBBte7B3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/georgetown-running-company-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 71,
#    'categories': [{'alias': 'sportswear', 'title': 'Sports Wear'},
#     {'alias': 'shoes', 'title': 'Shoe Stores'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.905662, 'longitude': -77.067937},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3401 M St NW',
#     'address2': 'Between N 34th St & Key Brg',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20007',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['3401 M St NW',
#      'Between N 34th St & Key Brg',
#      'Washington, DC 20007']},
#    'phone': '+12023378626',
#    'display_phone': '(202) 337-8626',
#    'distance': 3287.3926804099874},
#   {'id': 'ENVpHrjkP1WL4GcsErAcFw',
#    'alias': 'mount-rainier-bike-co-op-mount-rainier',
#    'name': 'Mount Rainier Bike Co-op',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h7vvGsghf9E2a0Zb-zRJKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mount-rainier-bike-co-op-mount-rainier?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 3,
#    'categories': [{'alias': 'nonprofit',
#      'title': 'Community Service/Non-Profit'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.93879, 'longitude': -76.95833},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3601 Bunker Hill Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Mount Rainier',
#     'zip_code': '20712',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['3601 Bunker Hill Rd', 'Mount Rainier, MD 20712']},
#    'phone': '+13012772110',
#    'display_phone': '(301) 277-2110',
#    'distance': 6962.020330339948},
#   {'id': 'ZAp1Eg9osOz3vBJQhUIWuw',
#    'alias': 'rats-cycles-springfield-3',
#    'name': 'Rats Cycles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CIjkbvubil2QBgMxc330lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rats-cycles-springfield-3?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 20,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.7514685, 'longitude': -77.2642205},
#    'transactions': [],
#    'location': {'address1': '7509 Huntsman Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Springfield',
#     'zip_code': '22153',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['7509 Huntsman Blvd', 'Springfield, VA 22153']},
#    'phone': '+17032693310',
#    'display_phone': '(703) 269-3310',
#    'distance': 26931.369430587252},
#   {'id': 'vd73Kr5WsTYWpW6nwZ9cxw',
#    'alias': 'dunn-lewis-washington',
#    'name': 'Dunn Lewis',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/khH_Ift8P6DTzizdpGKOjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dunn-lewis-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 3,
#    'categories': [{'alias': 'motorcyclinggear', 'title': 'Motorcycle Gear'},
#     {'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.91502, 'longitude': -76.98467},
#    'transactions': [],
#    'location': {'address1': '2007 Fenwick St NE',
#     'address2': None,
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20002',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['2007 Fenwick St NE', 'Washington, DC 20002']},
#    'phone': '+12025256527',
#    'display_phone': '(202) 525-6527',
#    'distance': 3998.6388201345826},
#   {'id': 'xplJcyRK765GeB2-22qL-g',
#    'alias': 'velofix-fairfax-2',
#    'name': 'velofix',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PEfSx8w1jrSRyf3XcEXpxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/velofix-fairfax-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 13,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.85378, 'longitude': -77.34069},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': '',
#     'address3': None,
#     'city': 'Fairfax',
#     'zip_code': '22030',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['Fairfax, VA 22030']},
#    'phone': '+18558356349',
#    'display_phone': '(855) 835-6349',
#    'distance': 24940.757451860598},
#   {'id': 'LQFwqXVcL2P6Be9_Uu8z2g',
#    'alias': 'contes-bike-shop-alexandria',
#    'name': "Conte's Bike Shop",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rueK6R915AuQXeroMTqqDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/contes-bike-shop-alexandria?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 16,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.80554, 'longitude': -77.05154},
#    'transactions': [],
#    'location': {'address1': '1100 King St',
#     'address2': None,
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22314',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['1100 King St', 'Alexandria, VA 22314']},
#    'phone': '+15714827701',
#    'display_phone': '(571) 482-7701',
#    'distance': 11918.269117421014},
#   {'id': 'HQKlHmtix1zwT0EpWmBMgQ',
#    'alias': 'sun-and-ski-sports-falls-church',
#    'name': 'Sun & Ski Sports',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3h3z2PuhMvdC60SIidUkhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sun-and-ski-sports-falls-church?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 54,
#    'categories': [{'alias': 'shoes', 'title': 'Shoe Stores'},
#     {'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'skishops', 'title': 'Ski & Snowboard Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.8697635, 'longitude': -77.151829},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6280 Seven Corners Ctr',
#     'address2': '',
#     'address3': '',
#     'city': 'Falls Church',
#     'zip_code': '22044',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['6280 Seven Corners Ctr', 'Falls Church, VA 22044']},
#    'phone': '+17035211700',
#    'display_phone': '(703) 521-1700',
#    'distance': 11460.293180994146},
#   {'id': 'apgO5AzViXPsViL1e0uIXA',
#    'alias': 'spokes-etc-bicycles-vienna-2',
#    'name': 'Spokes Etc. Bicycles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-C4CtVnukgBwBzSdxNwkNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spokes-etc-bicycles-vienna-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 105,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'},
#     {'alias': 'outdoorgear', 'title': 'Outdoor Gear'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.9042278, 'longitude': -77.262087},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '224 Maple Ave E',
#     'address2': '',
#     'address3': '',
#     'city': 'Vienna',
#     'zip_code': '22180',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['224 Maple Ave E', 'Vienna, VA 22180']},
#    'phone': '+17032812004',
#    'display_phone': '(703) 281-2004',
#    'distance': 20055.2238329221},
#   {'id': 'cxI4w3PiIoLJzEdLtgIfyA',
#    'alias': 'survival-services-washington',
#    'name': 'Survival Services',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/survival-services-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 12,
#    'categories': [{'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.93234, 'longitude': -77.04373},
#    'transactions': [],
#    'location': {'address1': '1856 Park Rd NW',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20010',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['1856 Park Rd NW', 'Washington, DC 20010']},
#    'phone': '+12022349229',
#    'display_phone': '(202) 234-9229',
#    'distance': 2597.800164569895},
#   {'id': 'Z8r2tI98-fNTREXPIjbNRw',
#    'alias': 'big-wheel-bikes-potomac',
#    'name': 'Big Wheel Bikes',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jmRGgDTBLc4PuJj_XRa1SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-wheel-bikes-potomac?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 20,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.018255, 'longitude': -77.208625},
#    'transactions': [],
#    'location': {'address1': '9931 Falls Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Potomac',
#     'zip_code': '20854',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['9931 Falls Rd', 'Potomac, MD 20854']},
#    'phone': '+13012991660',
#    'display_phone': '(301) 299-1660',
#    'distance': 19436.33975676944},
#   {'id': 'JFZr74r1UZIOAnYbJ_TehQ',
#    'alias': 'bike-club-falls-church',
#    'name': 'Bike Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/laN4bsoPnnsp-6vWuYbtvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bike-club-falls-church?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 71,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.8800201, 'longitude': -77.1760406},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '438 S Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Falls Church',
#     'zip_code': '22046',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['438 S Washington St', 'Falls Church, VA 22046']},
#    'phone': '+17035324116',
#    'display_phone': '(703) 532-4116',
#    'distance': 13056.007957354928},
#   {'id': 'Flml5W1-uOi79B-PFVBcrw',
#    'alias': 'capital-bikeshare-washington',
#    'name': 'Capital Bikeshare',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ksadp4zbwKUJNQVWA6rrww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/capital-bikeshare-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 385,
#    'categories': [{'alias': 'bikesharing', 'title': 'Bike Sharing'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 38.9319038391113,
#     'longitude': -77.0330581665039},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20010',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['Washington, DC 20010']},
#    'phone': '+18774302453',
#    'display_phone': '(877) 430-2453',
#    'distance': 2514.2437583937626},
#   {'id': '9oG1-aB1P2qF5efz7f-WGw',
#    'alias': 'conversion-ebikes-fairmount-heights-2',
#    'name': 'Conversion Ebikes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/21_8dmXX6qdH0Tupnq75Ig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/conversion-ebikes-fairmount-heights-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 1,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.90091, 'longitude': -76.91766},
#    'transactions': [],
#    'location': {'address1': '817 57th Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Fairmount Heights',
#     'zip_code': '20743',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['817 57th Pl', 'Fairmount Heights, MD 20743']},
#    'phone': '+12403890723',
#    'display_phone': '(240) 389-0723',
#    'distance': 9849.081779338898},
#   {'id': 'N-P-QHW1si1Fhfgr1m_82w',
#    'alias': 'bike-werks-olney',
#    'name': 'Bike Werks',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8Ztr8oW5uT_7O1dW3dXNIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bike-werks-olney?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 9,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.1512680053711,
#     'longitude': -77.062744140625},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': None,
#     'address3': '',
#     'city': 'Olney',
#     'zip_code': '20832',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['Olney, MD 20832']},
#    'phone': '+13013106765',
#    'display_phone': '(301) 310-6765',
#    'distance': 26264.899425346593},
#   {'id': 'QozXLbPfhyjdN6O2et3Aaw',
#    'alias': 'washington-and-old-dominion-regional-park-arlington',
#    'name': 'Washington & Old Dominion Regional Park',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6X6_oUKkQ5OXwAGxYMjpCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/washington-and-old-dominion-regional-park-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 8,
#    'categories': [{'alias': 'hiking', 'title': 'Hiking'},
#     {'alias': 'parks', 'title': 'Parks'},
#     {'alias': 'mountainbiking', 'title': 'Mountain Biking'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8443426116282,
#     'longitude': -77.0855873506808},
#    'transactions': [],
#    'location': {'address1': 'S Four Mile Run Dr And S Shirlington Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22206',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['S Four Mile Run Dr And S Shirlington Rd',
#      'Arlington, VA 22206']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8832.463501673019},
#   {'id': 'F4fPzyVvH4Yk4hr-q3SUtw',
#    'alias': '1-ebikes-arlington',
#    'name': '#1 Ebikes',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ix2v8sd9FtMEIzQqfNh9jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/1-ebikes-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 5,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'},
#     {'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.88219, 'longitude': -77.10001},
#    'transactions': [],
#    'location': {'address1': '822 N Kenmore St',
#     'address2': '',
#     'address3': None,
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['822 N Kenmore St', 'Arlington, VA 22201']},
#    'phone': '+17036770147',
#    'display_phone': '(703) 677-0147',
#    'distance': 6814.04466473661},
#   {'id': 'n6qU8LGD6zgerfDgZtqTzw',
#    'alias': 'rei-baileys-crossroads',
#    'name': 'REI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9ram60jRGKD0jX53JwC9Ow/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rei-baileys-crossroads?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 131,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'outdoorgear', 'title': 'Outdoor Gear'},
#     {'alias': 'sportswear', 'title': 'Sports Wear'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.849132, 'longitude': -77.123237},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3509 Carlin Springs Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Baileys Crossroads',
#     'zip_code': '22041',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3509 Carlin Springs Rd',
#      'Baileys Crossroads, VA 22041']},
#    'phone': '+17033799400',
#    'display_phone': '(703) 379-9400',
#    'distance': 10606.269722762978},
#   {'id': 'z9Enbz9rh9Ku91dN7TDJJw',
#    'alias': 'bicycle-pro-shop-springfield',
#    'name': 'Bicycle Pro Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HSY3FFFbOnzXarZVSqyq-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bicycle-pro-shop-springfield?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 7,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.8099961, 'longitude': -77.2215107},
#    'transactions': [],
#    'location': {'address1': '5230 Port Royal Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Springfield',
#     'zip_code': '22151',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['5230 Port Royal Rd', 'Springfield, VA 22151']},
#    'phone': '+15712974227',
#    'display_phone': '(571) 297-4227',
#    'distance': 20117.023898164345},
#   {'id': 'HXNUcGNuX1pyVEeufZ3Axw',
#    'alias': 'casual-adventure-outfitters-arlington-3',
#    'name': 'Casual Adventure Outfitters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/niDWn7yayg_ER-p2jBMc9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/casual-adventure-outfitters-arlington-3?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 52,
#    'categories': [{'alias': 'outdoorgear', 'title': 'Outdoor Gear'},
#     {'alias': 'sportswear', 'title': 'Sports Wear'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.886231, 'longitude': -77.102768},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3451 Washington Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3451 Washington Blvd', 'Arlington, VA 22201']},
#    'phone': '+17035270600',
#    'display_phone': '(703) 527-0600',
#    'distance': 6835.72274933798},
#   {'id': '-qsvE9uIu3DdiAYJq9RO4Q',
#    'alias': 'trifecta-tuning-arlington',
#    'name': 'Trifecta Tuning',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G_pw5kSgpkVV7AmkkZD4-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trifecta-tuning-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 1,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.88365, 'longitude': -77.09375},
#    'transactions': [],
#    'location': {'address1': '920 N Garfield St',
#     'address2': '',
#     'address3': None,
#     'city': 'Arlington',
#     'zip_code': '22201',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['920 N Garfield St', 'Arlington, VA 22201']},
#    'phone': '+15712285662',
#    'display_phone': '(571) 228-5662',
#    'distance': 6268.746393943917},
#   {'id': 'sWNJA-88ZhypcD8ak1_tRw',
#    'alias': 'bike-and-roll-alexandria',
#    'name': 'Bike and Roll',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N0StcOk__in5UiV9KKsOdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bike-and-roll-alexandria?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 20,
#    'categories': [{'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'biketours', 'title': 'Bike tours'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.803926, 'longitude': -77.0399273},
#    'transactions': [],
#    'location': {'address1': 'One Wales Alley',
#     'address2': '',
#     'address3': '',
#     'city': 'Alexandria',
#     'zip_code': '22314',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['One Wales Alley', 'Alexandria, VA 22314']},
#    'phone': '+12028422453',
#    'display_phone': '(202) 842-2453',
#    'distance': 11965.771318486175},
#   {'id': '0mZkuEENHtR0QqRiaC6QOQ',
#    'alias': 'myers-cycle-engineering-kensington',
#    'name': 'Myers Cycle Engineering',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nszNVvWV-u0mKbykhppLUA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/myers-cycle-engineering-kensington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 23,
#    'categories': [{'alias': 'motorcycledealers',
#      'title': 'Motorcycle Dealers'},
#     {'alias': 'autorepair', 'title': 'Auto Repair'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.02907, 'longitude': -77.07826},
#    'transactions': [],
#    'location': {'address1': '10529 Summit Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kensington',
#     'zip_code': '20895',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['10529 Summit Ave', 'Kensington, MD 20895']},
#    'phone': '+13018970050',
#    'display_phone': '(301) 897-0050',
#    'distance': 13723.24886728278},
#   {'id': '5u8J-RDLWq1FEdagVUVrgw',
#    'alias': 'rei-mclean',
#    'name': 'REI',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gqpwNV9T75MLV2pkYEeT_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rei-mclean?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 57,
#    'categories': [{'alias': 'outdoorgear', 'title': 'Outdoor Gear'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 38.9181168652733,
#     'longitude': -77.2288927116479},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8209 Watson St',
#     'address2': '',
#     'address3': '',
#     'city': 'McLean',
#     'zip_code': '22102',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['8209 Watson St', 'McLean, VA 22102']},
#    'phone': '+17035061938',
#    'display_phone': '(703) 506-1938',
#    'distance': 17169.359905198522},
#   {'id': 'Kb6V4HAoIabchYf6cxXEfQ',
#    'alias': 'rei-north-bethesda-2',
#    'name': 'REI',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qTIj5vMo4SMtpUKJKzDn5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rei-north-bethesda-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 135,
#    'categories': [{'alias': 'sportswear', 'title': 'Sports Wear'},
#     {'alias': 'outdoorgear', 'title': 'Outdoor Gear'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.050862, 'longitude': -77.1158990957009},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '910 Rose Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'North Bethesda',
#     'zip_code': '20852',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['910 Rose Ave', 'North Bethesda, MD 20852']},
#    'phone': '+13017701751',
#    'display_phone': '(301) 770-1751',
#    'distance': 17180.20770119785},
#   {'id': '9O8jiDSt_0pJYCd-DoN4Xg',
#    'alias': 'everything-esmonde-washington',
#    'name': 'Everything Esmonde',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/everything-esmonde-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 2,
#    'categories': [{'alias': 'bike_repair_maintenance',
#      'title': 'Bike Repair/Maintenance'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.96064, 'longitude': -77.02674},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20011',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['Washington, DC 20011']},
#    'phone': '+12026572316',
#    'display_phone': '(202) 657-2316',
#    'distance': 4509.549913054896},
#   {'id': 'FV17oLvqbkYnSZL2hemVgQ',
#    'alias': 'the-green-commuter-silver-spring',
#    'name': 'The Green Commuter',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-green-commuter-silver-spring?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 19,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.007232, 'longitude': -77.04999},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2353 Distribution Cir',
#     'address2': '',
#     'address3': '',
#     'city': 'Silver Spring',
#     'zip_code': '20910',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['2353 Distribution Cir', 'Silver Spring, MD 20910']},
#    'phone': '+13015806967',
#    'display_phone': '(301) 580-6967',
#    'distance': 10798.260590491553},
#   {'id': 'cerXy3JuutREkWNSFhwm3A',
#    'alias': 'dicks-sporting-goods-wheaton',
#    'name': "DICK'S Sporting Goods",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/42ekw7mVnDMp6waMnjsqnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dicks-sporting-goods-wheaton?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 30,
#    'categories': [{'alias': 'sportswear', 'title': 'Sports Wear'},
#     {'alias': 'outdoorgear', 'title': 'Outdoor Gear'},
#     {'alias': 'fitnessequipment', 'title': 'Fitness/Exercise Equipment'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.035234, 'longitude': -77.054831},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '11160 Veirs Mill Rd',
#     'address2': 'Wheaton Plaza',
#     'address3': '',
#     'city': 'Wheaton',
#     'zip_code': '20902',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['11160 Veirs Mill Rd',
#      'Wheaton Plaza',
#      'Wheaton, MD 20902']},
#    'phone': '+13019333494',
#    'display_phone': '(301) 933-3494',
#    'distance': 13939.29824051602},
#   {'id': 'U-xTh_1xJWtWrhnEaJ-5mA',
#    'alias': 'veloworks-arlington',
#    'name': 'VeloWorks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4xuXltxmhNo5vGNhDttcTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/veloworks-arlington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 1,
#    'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'amateursportsteams', 'title': 'Amateur Sports Teams'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.83235, 'longitude': -77.09125},
#    'transactions': [],
#    'location': {'address1': '3513 S Wakefield St',
#     'address2': '',
#     'address3': '',
#     'city': 'Arlington',
#     'zip_code': '22206',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['3513 S Wakefield St', 'Arlington, VA 22206']},
#    'phone': '+17039656113',
#    'display_phone': '(703) 965-6113',
#    'distance': 10268.277173092662},
#   {'id': 'g5p1S16VbMLWWfeqcdt4Ag',
#    'alias': 'cycle-gear-springfield-3',
#    'name': 'Cycle Gear',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EGbgIdbOsBPasF3y_hJqHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cycle-gear-springfield-3?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 19,
#    'categories': [{'alias': 'motorcyclinggear', 'title': 'Motorcycle Gear'},
#     {'alias': 'tires', 'title': 'Tires'},
#     {'alias': 'autopartssupplies', 'title': 'Auto Parts & Supplies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 38.772617, 'longitude': -77.18431},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7000 Spring Garden Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Springfield',
#     'zip_code': '22150',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['7000 Spring Garden Dr', 'Springfield, VA 22150']},
#    'phone': '+17039400958',
#    'display_phone': '(703) 940-0958',
#    'distance': 20369.29983122634},
#   {'id': 'wfvJblf21s3BGSzo8tI0VA',
#    'alias': 'modern-classics-washington',
#    'name': 'Modern Classics',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bLeX3kIWslxFT9Cg0KGsDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/modern-classics-washington?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 36,
#    'categories': [{'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'},
#     {'alias': 'motorcycledealers', 'title': 'Motorcycle Dealers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9174456, 'longitude': -76.9910078},
#    'transactions': [],
#    'location': {'address1': '955 V St NE',
#     'address2': '',
#     'address3': '',
#     'city': 'Washington, DC',
#     'zip_code': '20018',
#     'country': 'US',
#     'state': 'DC',
#     'display_address': ['955 V St NE', 'Washington, DC 20018']},
#    'phone': '+12022481926',
#    'display_phone': '(202) 248-1926',
#    'distance': 3496.4820923942148},
#   {'id': '0-I17M2edC0OO8cpPzP0pg',
#    'alias': 'precision-cycle-works-beltsville-2',
#    'name': 'Precision Cycle Works',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/precision-cycle-works-beltsville-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 2,
#    'categories': [{'alias': 'motorcyclerepair', 'title': 'Motorcycle Repair'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.0259857177734,
#     'longitude': -76.9087829589844},
#    'transactions': [],
#    'location': {'address1': '10745 Tucker St',
#     'address2': 'Unit 3',
#     'address3': '',
#     'city': 'Beltsville',
#     'zip_code': '20705',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['10745 Tucker St', 'Unit 3', 'Beltsville, MD 20705']},
#    'phone': '+13019375783',
#    'display_phone': '(301) 937-5783',
#    'distance': 16532.71547448433},
#   {'id': 'wsqXGUVytcMziH31LRm0mw',
#    'alias': 'electric-cycling-house-bethesda-2',
#    'name': 'Electric Cycling House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FTGChHYDCvMqjSwRNyvedg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/electric-cycling-house-bethesda-2?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 2,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 38.98463, 'longitude': -77.09525},
#    'transactions': [],
#    'location': {'address1': '3 Bethesda Metro Ctr',
#     'address2': 'Ste B002',
#     'address3': None,
#     'city': 'Bethesda',
#     'zip_code': '20814',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['3 Bethesda Metro Ctr',
#      'Ste B002',
#      'Bethesda, MD 20814']},
#    'phone': '+12405776200',
#    'display_phone': '(240) 577-6200',
#    'distance': 9903.923232282828},
#   {'id': 'p4DxQUVlgc8233QGxfd3LQ',
#    'alias': 'electroscooterworks-beltsville',
#    'name': 'ElectroScooterWorks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0DJCm-Mdtp2wlSivjrzyKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/electroscooterworks-beltsville?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 3,
#    'categories': [{'alias': 'skateshops', 'title': 'Skate Shops'},
#     {'alias': 'motorepairs', 'title': 'Motorsport Vehicle Repairs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.05356, 'longitude': -76.88917},
#    'transactions': [],
#    'location': {'address1': '6751 Mid Cities Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Beltsville',
#     'zip_code': '20705',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['6751 Mid Cities Ave', 'Beltsville, MD 20705']},
#    'phone': '+12406871678',
#    'display_phone': '(240) 687-1678',
#    'distance': 19950.240557692498},
#   {'id': 'P2u1l1A36zLodZS9S8YLpw',
#    'alias': 'johnson-fitness-and-wellness-mclean',
#    'name': 'Johnson Fitness & Wellness',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F5MS53vLQlpyzNWa_pHsbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnson-fitness-and-wellness-mclean?adjust_creative=dpB8uUsFa0hX6mpY12y4ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dpB8uUsFa0hX6mpY12y4ew',
#    'review_count': 24,
#    'categories': [{'alias': 'fitnessequipment',
#      'title': 'Fitness/Exercise Equipment'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.9173889, 'longitude': -77.2268829},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8133 Watson St.',
#     'address2': '',
#     'address3': '',
#     'city': 'McLean',
#     'zip_code': '22102',
#     'country': 'US',
#     'state': 'VA',
#     'display_address': ['8133 Watson St.', 'McLean, VA 22102']},
#    'phone': '+17035069200',
#    'display_phone': '(703) 506-9200',
#    'distance': 17002.203685446693}],
#  'total': 146,
#  'region': {'center': {'longitude': -77.0306396484375,
#    'latitude': 38.911293573163775}}}

# %%
data2_df = pd.DataFrame(results2.json()['businesses'])
data2_df
# Out:
#                         id                                              alias  \
# 0   aCcwo1rqNDc2EdNbrGQYlw                 college-park-bicycles-college-park
# 1   aes6SOPlGBSi4FoHknWbUQ              east-potomac-golf-course-washington-2
# 2   q_CSikkPgszHI5LvEWU6HQ                        fat-tire-tours-washington-2
# 3   OG5nM2il0cp0MaK6c9AJAw                      spokes-etc-bicycles-arlington
# 4   r_3e6XcQN2Hb_h6U_qiSwQ                           handy-bikes-alexandria-2
# 5   UiAA5CKvEcni6IF3xoWZjw              cycles-of-silver-spring-silver-spring
# 6   5UZFR7qk81jwYF3n_ZwJEA   bikenetic-full-service-bicycle-shop-falls-church
# 7   EvLmGhOsWKkXGLGhGKVM3Q                      clinton-cycles-camp-springs-2
# 8   iIJqWC2hEsxG8NUUa9bvtA                mittens-pop-up-bike-shop-washington
# 9   ZNNwWunapph3PAWhq4OwDg           a-and-j-cycle-performance-upper-marlboro
# 10  Jy6gV4N_57LR8bu67cQzrA                      crossroads-cycle-falls-church
# 11  vy2H6Xf55NhC0938QIzA4Q                     spokes-etc-bicycles-alexandria
# 12  fA06wgVa8CwCZOWTL8cw3A                        unlimited-biking-washington
# 13  rLBUUBSBArIy9hxJncaRUg                          hybrid-pedals-arlington-2
# 14  aowukYOxbvpUuNKvxMeOWA                      contes-bike-shop-falls-church
# 15  EgGkiQUAEd8iUReQfJyFZg                        pacers-running-washington-3
# 16  oYElueOSr_rUkgisyw7Gnw              georgetown-running-company-washington
# 17  ENVpHrjkP1WL4GcsErAcFw             mount-rainier-bike-co-op-mount-rainier
# 18  ZAp1Eg9osOz3vBJQhUIWuw                          rats-cycles-springfield-3
# 19  vd73Kr5WsTYWpW6nwZ9cxw                              dunn-lewis-washington
# 20  xplJcyRK765GeB2-22qL-g                                  velofix-fairfax-2
# 21  LQFwqXVcL2P6Be9_Uu8z2g                        contes-bike-shop-alexandria
# 22  HQKlHmtix1zwT0EpWmBMgQ                    sun-and-ski-sports-falls-church
# 23  apgO5AzViXPsViL1e0uIXA                       spokes-etc-bicycles-vienna-2
# 24  cxI4w3PiIoLJzEdLtgIfyA                       survival-services-washington
# 25  Z8r2tI98-fNTREXPIjbNRw                            big-wheel-bikes-potomac
# 26  JFZr74r1UZIOAnYbJ_TehQ                             bike-club-falls-church
# 27  Flml5W1-uOi79B-PFVBcrw                       capital-bikeshare-washington
# 28  9oG1-aB1P2qF5efz7f-WGw              conversion-ebikes-fairmount-heights-2
# 29  N-P-QHW1si1Fhfgr1m_82w                                   bike-werks-olney
# 30  QozXLbPfhyjdN6O2et3Aaw  washington-and-old-dominion-regional-park-arli...
# 31  F4fPzyVvH4Yk4hr-q3SUtw                                 1-ebikes-arlington
# 32  n6qU8LGD6zgerfDgZtqTzw                             rei-baileys-crossroads
# 33  z9Enbz9rh9Ku91dN7TDJJw                       bicycle-pro-shop-springfield
# 34  HXNUcGNuX1pyVEeufZ3Axw            casual-adventure-outfitters-arlington-3
# 35  -qsvE9uIu3DdiAYJq9RO4Q                          trifecta-tuning-arlington
# 36  sWNJA-88ZhypcD8ak1_tRw                           bike-and-roll-alexandria
# 37  0mZkuEENHtR0QqRiaC6QOQ                 myers-cycle-engineering-kensington
# 38  5u8J-RDLWq1FEdagVUVrgw                                         rei-mclean
# 39  Kb6V4HAoIabchYf6cxXEfQ                               rei-north-bethesda-2
# 40  9O8jiDSt_0pJYCd-DoN4Xg                      everything-esmonde-washington
# 41  FV17oLvqbkYnSZL2hemVgQ                   the-green-commuter-silver-spring
# 42  cerXy3JuutREkWNSFhwm3A                       dicks-sporting-goods-wheaton
# 43  U-xTh_1xJWtWrhnEaJ-5mA                                veloworks-arlington
# 44  g5p1S16VbMLWWfeqcdt4Ag                           cycle-gear-springfield-3
# 45  wfvJblf21s3BGSzo8tI0VA                         modern-classics-washington
# 46  0-I17M2edC0OO8cpPzP0pg                 precision-cycle-works-beltsville-2
# 47  wsqXGUVytcMziH31LRm0mw                  electric-cycling-house-bethesda-2
# 48  p4DxQUVlgc8233QGxfd3LQ                     electroscooterworks-beltsville
# 49  P2u1l1A36zLodZS9S8YLpw                johnson-fitness-and-wellness-mclean
#
#                                        name  \
# 0                     College Park Bicycles
# 1                  East Potomac Golf Course
# 2                            Fat Tire Tours
# 3                      Spokes Etc. Bicycles
# 4                               Handy Bikes
# 5                   Cycles of Silver Spring
# 6       Bikenetic Full Service Bicycle Shop
# 7                            Clinton Cycles
# 8                  Mittens Pop Up Bike Shop
# 9                   A & J Cycle Performance
# 10                         Crossroads Cycle
# 11                     Spokes Etc. Bicycles
# 12                         Unlimited Biking
# 13                            Hybrid Pedals
# 14                        Conte's Bike Shop
# 15                           Pacers Running
# 16               Georgetown Running Company
# 17                 Mount Rainier Bike Co-op
# 18                              Rats Cycles
# 19                               Dunn Lewis
# 20                                  velofix
# 21                        Conte's Bike Shop
# 22                         Sun & Ski Sports
# 23                     Spokes Etc. Bicycles
# 24                        Survival Services
# 25                          Big Wheel Bikes
# 26                                Bike Club
# 27                        Capital Bikeshare
# 28                        Conversion Ebikes
# 29                               Bike Werks
# 30  Washington & Old Dominion Regional Park
# 31                                #1 Ebikes
# 32                                      REI
# 33                         Bicycle Pro Shop
# 34              Casual Adventure Outfitters
# 35                          Trifecta Tuning
# 36                            Bike and Roll
# 37                  Myers Cycle Engineering
# 38                                      REI
# 39                                      REI
# 40                       Everything Esmonde
# 41                       The Green Commuter
# 42                    DICK'S Sporting Goods
# 43                                VeloWorks
# 44                               Cycle Gear
# 45                          Modern Classics
# 46                    Precision Cycle Works
# 47                   Electric Cycling House
# 48                      ElectroScooterWorks
# 49               Johnson Fitness & Wellness
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/3QaD5Q...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/L08dmj...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/Ul2-Qj...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/0fAT5H...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/Rp3Ctc...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/Lo2Rb1...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/x9thH2...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/1xH4G9...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/6MQZWo...      False
# 9                                                          False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/p2Vum8...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/Kfn_cx...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/T8747k...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/azRZKR...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/Fx-4X_...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/hyl4_c...      False
# 16  https://s3-media1.fl.yelpcdn.com/bphoto/4TK3z7...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/h7vvGs...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/CIjkbv...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/khH_If...      False
# 20  https://s3-media1.fl.yelpcdn.com/bphoto/PEfSx8...      False
# 21  https://s3-media1.fl.yelpcdn.com/bphoto/rueK6R...      False
# 22  https://s3-media3.fl.yelpcdn.com/bphoto/3h3z2P...      False
# 23  https://s3-media1.fl.yelpcdn.com/bphoto/-C4CtV...      False
# 24                                                         False
# 25  https://s3-media3.fl.yelpcdn.com/bphoto/jmRGgD...      False
# 26  https://s3-media1.fl.yelpcdn.com/bphoto/laN4bs...      False
# 27  https://s3-media3.fl.yelpcdn.com/bphoto/ksadp4...      False
# 28  https://s3-media4.fl.yelpcdn.com/bphoto/21_8dm...      False
# 29  https://s3-media3.fl.yelpcdn.com/bphoto/8Ztr8o...      False
# 30  https://s3-media4.fl.yelpcdn.com/bphoto/6X6_oU...      False
# 31  https://s3-media4.fl.yelpcdn.com/bphoto/ix2v8s...      False
# 32  https://s3-media4.fl.yelpcdn.com/bphoto/9ram60...      False
# 33  https://s3-media3.fl.yelpcdn.com/bphoto/HSY3FF...      False
# 34  https://s3-media2.fl.yelpcdn.com/bphoto/niDWn7...      False
# 35  https://s3-media1.fl.yelpcdn.com/bphoto/G_pw5k...      False
# 36  https://s3-media2.fl.yelpcdn.com/bphoto/N0StcO...      False
# 37  https://s3-media1.fl.yelpcdn.com/bphoto/nszNVv...      False
# 38  https://s3-media2.fl.yelpcdn.com/bphoto/gqpwNV...      False
# 39  https://s3-media3.fl.yelpcdn.com/bphoto/qTIj5v...      False
# 40                                                         False
# 41                                                         False
# 42  https://s3-media1.fl.yelpcdn.com/bphoto/42ekw7...      False
# 43  https://s3-media2.fl.yelpcdn.com/bphoto/4xuXlt...      False
# 44  https://s3-media2.fl.yelpcdn.com/bphoto/EGbgId...      False
# 45  https://s3-media3.fl.yelpcdn.com/bphoto/bLeX3k...      False
# 46                                                         False
# 47  https://s3-media4.fl.yelpcdn.com/bphoto/FTGChH...      False
# 48  https://s3-media2.fl.yelpcdn.com/bphoto/0DJCm-...      False
# 49  https://s3-media2.fl.yelpcdn.com/bphoto/F5MS53...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/college-park-bicycles...            33
# 1   https://www.yelp.com/biz/east-potomac-golf-cou...           114
# 2   https://www.yelp.com/biz/fat-tire-tours-washin...            30
# 3   https://www.yelp.com/biz/spokes-etc-bicycles-a...            19
# 4   https://www.yelp.com/biz/handy-bikes-alexandri...            46
# 5   https://www.yelp.com/biz/cycles-of-silver-spri...            30
# 6   https://www.yelp.com/biz/bikenetic-full-servic...            95
# 7   https://www.yelp.com/biz/clinton-cycles-camp-s...            15
# 8   https://www.yelp.com/biz/mittens-pop-up-bike-s...             4
# 9   https://www.yelp.com/biz/a-and-j-cycle-perform...             8
# 10  https://www.yelp.com/biz/crossroads-cycle-fall...            37
# 11  https://www.yelp.com/biz/spokes-etc-bicycles-a...            48
# 12  https://www.yelp.com/biz/unlimited-biking-wash...             3
# 13  https://www.yelp.com/biz/hybrid-pedals-arlingt...            24
# 14  https://www.yelp.com/biz/contes-bike-shop-fall...            37
# 15  https://www.yelp.com/biz/pacers-running-washin...            16
# 16  https://www.yelp.com/biz/georgetown-running-co...            71
# 17  https://www.yelp.com/biz/mount-rainier-bike-co...             3
# 18  https://www.yelp.com/biz/rats-cycles-springfie...            20
# 19  https://www.yelp.com/biz/dunn-lewis-washington...             3
# 20  https://www.yelp.com/biz/velofix-fairfax-2?adj...            13
# 21  https://www.yelp.com/biz/contes-bike-shop-alex...            16
# 22  https://www.yelp.com/biz/sun-and-ski-sports-fa...            54
# 23  https://www.yelp.com/biz/spokes-etc-bicycles-v...           105
# 24  https://www.yelp.com/biz/survival-services-was...            12
# 25  https://www.yelp.com/biz/big-wheel-bikes-potom...            20
# 26  https://www.yelp.com/biz/bike-club-falls-churc...            71
# 27  https://www.yelp.com/biz/capital-bikeshare-was...           385
# 28  https://www.yelp.com/biz/conversion-ebikes-fai...             1
# 29  https://www.yelp.com/biz/bike-werks-olney?adju...             9
# 30  https://www.yelp.com/biz/washington-and-old-do...             8
# 31  https://www.yelp.com/biz/1-ebikes-arlington?ad...             5
# 32  https://www.yelp.com/biz/rei-baileys-crossroad...           131
# 33  https://www.yelp.com/biz/bicycle-pro-shop-spri...             7
# 34  https://www.yelp.com/biz/casual-adventure-outf...            52
# 35  https://www.yelp.com/biz/trifecta-tuning-arlin...             1
# 36  https://www.yelp.com/biz/bike-and-roll-alexand...            20
# 37  https://www.yelp.com/biz/myers-cycle-engineeri...            23
# 38  https://www.yelp.com/biz/rei-mclean?adjust_cre...            57
# 39  https://www.yelp.com/biz/rei-north-bethesda-2?...           135
# 40  https://www.yelp.com/biz/everything-esmonde-wa...             2
# 41  https://www.yelp.com/biz/the-green-commuter-si...            19
# 42  https://www.yelp.com/biz/dicks-sporting-goods-...            30
# 43  https://www.yelp.com/biz/veloworks-arlington?a...             1
# 44  https://www.yelp.com/biz/cycle-gear-springfiel...            19
# 45  https://www.yelp.com/biz/modern-classics-washi...            36
# 46  https://www.yelp.com/biz/precision-cycle-works...             2
# 47  https://www.yelp.com/biz/electric-cycling-hous...             2
# 48  https://www.yelp.com/biz/electroscooterworks-b...             3
# 49  https://www.yelp.com/biz/johnson-fitness-and-w...            24
#
#                                            categories  rating  \
# 0   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.0
# 1   [{'alias': 'golf', 'title': 'Golf'}, {'alias':...     3.5
# 2   [{'alias': 'bikerentals', 'title': 'Bike Renta...     5.0
# 3   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 4   [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 5   [{'alias': 'motorcyclerepair', 'title': 'Motor...     4.5
# 6   [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 7   [{'alias': 'motorcycledealers', 'title': 'Moto...     2.5
# 8   [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 9   [{'alias': 'motorcyclerepair', 'title': 'Motor...     4.5
# 10  [{'alias': 'motorcycledealers', 'title': 'Moto...     4.5
# 11  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 12  [{'alias': 'bikerentals', 'title': 'Bike Renta...     3.5
# 13  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     5.0
# 14  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 15  [{'alias': 'shoes', 'title': 'Shoe Stores'}, {...     4.5
# 16  [{'alias': 'sportswear', 'title': 'Sports Wear...     4.0
# 17  [{'alias': 'nonprofit', 'title': 'Community Se...     3.5
# 18  [{'alias': 'bike_repair_maintenance', 'title':...     4.5
# 19  [{'alias': 'motorcyclinggear', 'title': 'Motor...     5.0
# 20  [{'alias': 'bike_repair_maintenance', 'title':...     4.5
# 21  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 22  [{'alias': 'shoes', 'title': 'Shoe Stores'}, {...     4.0
# 23  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.0
# 24  [{'alias': 'motorcyclerepair', 'title': 'Motor...     5.0
# 25             [{'alias': 'bikes', 'title': 'Bikes'}]     2.5
# 26             [{'alias': 'bikes', 'title': 'Bikes'}]     3.5
# 27  [{'alias': 'bikesharing', 'title': 'Bike Shari...     2.5
# 28  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 29  [{'alias': 'bike_repair_maintenance', 'title':...     4.0
# 30  [{'alias': 'hiking', 'title': 'Hiking'}, {'ali...     4.5
# 31  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 32  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     3.5
# 33  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...     4.5
# 34  [{'alias': 'outdoorgear', 'title': 'Outdoor Ge...     4.5
# 35  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 36  [{'alias': 'bikerentals', 'title': 'Bike Renta...     4.0
# 37  [{'alias': 'motorcycledealers', 'title': 'Moto...     5.0
# 38  [{'alias': 'outdoorgear', 'title': 'Outdoor Ge...     3.5
# 39  [{'alias': 'sportswear', 'title': 'Sports Wear...     3.5
# 40  [{'alias': 'bike_repair_maintenance', 'title':...     5.0
# 41             [{'alias': 'bikes', 'title': 'Bikes'}]     3.5
# 42  [{'alias': 'sportswear', 'title': 'Sports Wear...     2.5
# 43  [{'alias': 'healthtrainers', 'title': 'Trainer...     4.0
# 44  [{'alias': 'motorcyclinggear', 'title': 'Motor...     4.0
# 45  [{'alias': 'motorcyclerepair', 'title': 'Motor...     4.5
# 46  [{'alias': 'motorcyclerepair', 'title': 'Motor...     3.0
# 47             [{'alias': 'bikes', 'title': 'Bikes'}]     5.0
# 48  [{'alias': 'skateshops', 'title': 'Skate Shops...     4.5
# 49  [{'alias': 'fitnessequipment', 'title': 'Fitne...     4.5
#
#                                           coordinates transactions price  \
# 0       {'latitude': 38.97857, 'longitude': -76.9376}           []    $$
# 1    {'latitude': 38.874701, 'longitude': -77.027491}           []    $$
# 2   {'latitude': 38.8966086, 'longitude': -77.0502...           []   NaN
# 3      {'latitude': 38.87966, 'longitude': -77.10725}           []   NaN
# 4    {'latitude': 38.80741, 'longitude': -77.0972559}           []   NaN
# 5   {'latitude': 39.0017077714102, 'longitude': -7...           []   $$$
# 6    {'latitude': 38.887083, 'longitude': -77.166158}           []    $$
# 7        {'latitude': 38.797, 'longitude': -76.90156}           []   NaN
# 8      {'latitude': 38.91409, 'longitude': -77.02021}           []   NaN
# 9    {'latitude': 38.8335999, 'longitude': -76.86286}           []   NaN
# 10  {'latitude': 38.8489875793457, 'longitude': -7...           []   NaN
# 11   {'latitude': 38.775441, 'longitude': -77.059321}           []   $$$
# 12   {'latitude': 38.884514, 'longitude': -77.025102}           []   NaN
# 13  {'latitude': 38.8826293945312, 'longitude': -7...           []    $$
# 14  {'latitude': 38.8937204, 'longitude': -77.1873...           []    $$
# 15   {'latitude': 38.875186, 'longitude': -77.001304}           []    $$
# 16   {'latitude': 38.905662, 'longitude': -77.067937}           []    $$
# 17     {'latitude': 38.93879, 'longitude': -76.95833}           []     $
# 18  {'latitude': 38.7514685, 'longitude': -77.2642...           []   NaN
# 19     {'latitude': 38.91502, 'longitude': -76.98467}           []   NaN
# 20     {'latitude': 38.85378, 'longitude': -77.34069}           []   NaN
# 21     {'latitude': 38.80554, 'longitude': -77.05154}           []   NaN
# 22  {'latitude': 38.8697635, 'longitude': -77.151829}           []    $$
# 23  {'latitude': 38.9042278, 'longitude': -77.262087}           []    $$
# 24     {'latitude': 38.93234, 'longitude': -77.04373}           []   NaN
# 25   {'latitude': 39.018255, 'longitude': -77.208625}           []   NaN
# 26  {'latitude': 38.8800201, 'longitude': -77.1760...           []    $$
# 27  {'latitude': 38.9319038391113, 'longitude': -7...           []   NaN
# 28     {'latitude': 38.90091, 'longitude': -76.91766}           []   NaN
# 29  {'latitude': 39.1512680053711, 'longitude': -7...           []   NaN
# 30  {'latitude': 38.8443426116282, 'longitude': -7...           []   NaN
# 31     {'latitude': 38.88219, 'longitude': -77.10001}           []   NaN
# 32   {'latitude': 38.849132, 'longitude': -77.123237}           []    $$
# 33  {'latitude': 38.8099961, 'longitude': -77.2215...           []   NaN
# 34   {'latitude': 38.886231, 'longitude': -77.102768}           []    $$
# 35     {'latitude': 38.88365, 'longitude': -77.09375}           []   NaN
# 36  {'latitude': 38.803926, 'longitude': -77.0399273}           []   NaN
# 37     {'latitude': 39.02907, 'longitude': -77.07826}           []   NaN
# 38  {'latitude': 38.9181168652733, 'longitude': -7...           []    $$
# 39  {'latitude': 39.050862, 'longitude': -77.11589...           []   $$$
# 40     {'latitude': 38.96064, 'longitude': -77.02674}           []   NaN
# 41    {'latitude': 39.007232, 'longitude': -77.04999}           []    $$
# 42   {'latitude': 39.035234, 'longitude': -77.054831}           []    $$
# 43     {'latitude': 38.83235, 'longitude': -77.09125}           []   NaN
# 44    {'latitude': 38.772617, 'longitude': -77.18431}           []    $$
# 45  {'latitude': 38.9174456, 'longitude': -76.9910...           []   NaN
# 46  {'latitude': 39.0259857177734, 'longitude': -7...           []   NaN
# 47     {'latitude': 38.98463, 'longitude': -77.09525}           []   NaN
# 48     {'latitude': 39.05356, 'longitude': -76.88917}           []   NaN
# 49  {'latitude': 38.9173889, 'longitude': -77.2268...           []    $$
#
#                                              location         phone  \
# 0   {'address1': '7301 Baltimore Ave', 'address2':...  +13018642211
# 1   {'address1': '972 Ohio Dr SW', 'address2': '',...  +12025547660
# 2   {'address1': '502 23rd St NW', 'address2': Non...  +18777348687
# 3   {'address1': '3924 Wilson Blvd', 'address2': '...  +17032489600
# 4   {'address1': '3800 Wheeler Ave', 'address2': '...  +17035987795
# 5   {'address1': '8910 Brookville Rd', 'address2':...  +13015892453
# 6   {'address1': '201 W Jefferson St', 'address2':...  +17035347433
# 7   {'address1': '6709 Old Branch Ave', 'address2'...  +13014495900
# 8   {'address1': '', 'address2': '', 'address3': N...  +12026976790
# 9   {'address1': '8411 Old Marlboro Pike', 'addres...  +13015164144
# 10  {'address1': '5715 Leesburg Pike', 'address2':...  +17038203711
# 11  {'address1': '1506 Belle View Blvd', 'address2...  +17037658005
# 12  {'address1': '955 L'Enfant Plz SW', 'address2'...  +12028422453
# 13  {'address1': '822 N Kenmore St', 'address2': '...  +15712381729
# 14  {'address1': '1118 W Broad St', 'address2': No...  +17036390343
# 15  {'address1': '300 Tingey St SE', 'address2': '...  +12025541216
# 16  {'address1': '3401 M St NW', 'address2': 'Betw...  +12023378626
# 17  {'address1': '3601 Bunker Hill Rd', 'address2'...  +13012772110
# 18  {'address1': '7509 Huntsman Blvd', 'address2':...  +17032693310
# 19  {'address1': '2007 Fenwick St NE', 'address2':...  +12025256527
# 20  {'address1': None, 'address2': '', 'address3':...  +18558356349
# 21  {'address1': '1100 King St', 'address2': None,...  +15714827701
# 22  {'address1': '6280 Seven Corners Ctr', 'addres...  +17035211700
# 23  {'address1': '224 Maple Ave E', 'address2': ''...  +17032812004
# 24  {'address1': '1856 Park Rd NW', 'address2': ''...  +12022349229
# 25  {'address1': '9931 Falls Rd', 'address2': '', ...  +13012991660
# 26  {'address1': '438 S Washington St', 'address2'...  +17035324116
# 27  {'address1': '', 'address2': '', 'address3': '...  +18774302453
# 28  {'address1': '817 57th Pl', 'address2': None, ...  +12403890723
# 29  {'address1': '', 'address2': None, 'address3':...  +13013106765
# 30  {'address1': 'S Four Mile Run Dr And S Shirlin...
# 31  {'address1': '822 N Kenmore St', 'address2': '...  +17036770147
# 32  {'address1': '3509 Carlin Springs Rd', 'addres...  +17033799400
# 33  {'address1': '5230 Port Royal Rd', 'address2':...  +15712974227
# 34  {'address1': '3451 Washington Blvd', 'address2...  +17035270600
# 35  {'address1': '920 N Garfield St', 'address2': ...  +15712285662
# 36  {'address1': 'One Wales Alley', 'address2': ''...  +12028422453
# 37  {'address1': '10529 Summit Ave', 'address2': '...  +13018970050
# 38  {'address1': '8209 Watson St', 'address2': '',...  +17035061938
# 39  {'address1': '910 Rose Ave', 'address2': None,...  +13017701751
# 40  {'address1': '', 'address2': '', 'address3': '...  +12026572316
# 41  {'address1': '2353 Distribution Cir', 'address...  +13015806967
# 42  {'address1': '11160 Veirs Mill Rd', 'address2'...  +13019333494
# 43  {'address1': '3513 S Wakefield St', 'address2'...  +17039656113
# 44  {'address1': '7000 Spring Garden Dr', 'address...  +17039400958
# 45  {'address1': '955 V St NE', 'address2': '', 'a...  +12022481926
# 46  {'address1': '10745 Tucker St', 'address2': 'U...  +13019375783
# 47  {'address1': '3 Bethesda Metro Ctr', 'address2...  +12405776200
# 48  {'address1': '6751 Mid Cities Ave', 'address2'...  +12406871678
# 49  {'address1': '8133 Watson St.', 'address2': ''...  +17035069200
#
#      display_phone      distance
# 0   (301) 864-2211  10988.295163
# 1   (202) 554-7660   4078.018625
# 2   (877) 734-8687   2355.017238
# 3   (703) 248-9600   7518.980046
# 4   (703) 598-7795  12911.356410
# 5   (301) 589-2453  10255.724027
# 6   (703) 534-7433  12032.453839
# 7   (301) 449-5900  16923.794224
# 8   (202) 697-6790   1008.799142
# 9   (301) 516-4144  16912.389526
# 10  (703) 820-3711  10906.280569
# 11  (703) 765-8005  15307.656846
# 12  (202) 842-2453   3018.318749
# 13  (571) 238-1729   6814.044665
# 14  (703) 639-0343  13697.412524
# 15  (202) 554-1216   4743.794687
# 16  (202) 337-8626   3287.392680
# 17  (301) 277-2110   6962.020330
# 18  (703) 269-3310  26931.369431
# 19  (202) 525-6527   3998.638820
# 20  (855) 835-6349  24940.757452
# 21  (571) 482-7701  11918.269117
# 22  (703) 521-1700  11460.293181
# 23  (703) 281-2004  20055.223833
# 24  (202) 234-9229   2597.800165
# 25  (301) 299-1660  19436.339757
# 26  (703) 532-4116  13056.007957
# 27  (877) 430-2453   2514.243758
# 28  (240) 389-0723   9849.081779
# 29  (301) 310-6765  26264.899425
# 30                   8832.463502
# 31  (703) 677-0147   6814.044665
# 32  (703) 379-9400  10606.269723
# 33  (571) 297-4227  20117.023898
# 34  (703) 527-0600   6835.722749
# 35  (571) 228-5662   6268.746394
# 36  (202) 842-2453  11965.771318
# 37  (301) 897-0050  13723.248867
# 38  (703) 506-1938  17169.359905
# 39  (301) 770-1751  17180.207701
# 40  (202) 657-2316   4509.549913
# 41  (301) 580-6967  10798.260590
# 42  (301) 933-3494  13939.298241
# 43  (703) 965-6113  10268.277173
# 44  (703) 940-0958  20369.299831
# 45  (202) 248-1926   3496.482092
# 46  (301) 937-5783  16532.715474
# 47  (240) 577-6200   9903.923232
# 48  (240) 687-1678  19950.240558
# 49  (703) 506-9200  17002.203685

# %%
data2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             50 non-null     object
#  1   alias          50 non-null     object
#  2   name           50 non-null     object
#  3   image_url      50 non-null     object
#  4   is_closed      50 non-null     bool
#  5   url            50 non-null     object
#  6   review_count   50 non-null     int64
#  7   categories     50 non-null     object
#  8   rating         50 non-null     float64
#  9   coordinates    50 non-null     object
#  10  transactions   50 non-null     object
#  11  price          21 non-null     object
#  12  location       50 non-null     object
#  13  phone          50 non-null     object
#  14  display_phone  50 non-null     object
#  15  distance       50 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 6.0+ KB

# %%
data3_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-271f0aa28653> in <module>
# ----> 1 data3_df.info()
#
# NameError: name 'data3_df' is not defined

# %%
def parse_results2(results):
    # your code to parse the result to make them easier to insert into the DB
    results = results2.json()['businesses']
    parsed_data = []
    for business in results:
        if 'price' not in business:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], 'NaN',
                business['location']['zip_code'])
            parsed_data.append(biz_info)
        else:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], business['price'],
                business['location']['zip_code'])
            parsed_data.append(biz_info)
    return parsed_data

# %%
parsed_results = parse_results2(results)
parsed_results

# %%
bike_df2 = pd.DataFrame(parsed_results, columns = ('ID', 'Name', 'Is_Closed',
                                           'Review_Count', 'Rating', 'Price',
                                           'Zip_Code'))
bike_df2

# %%
bike_df2.to_csv('C:/Users/acumu/Documents/Flatiron/ds-east-042621-lectures/Phase_1/phase-1-project-yelp/bikedata2.csv', index = False)

# %%
bike_df2.shape

# %%
api_key = creds['key']
term = 'bike shop'
location = 'Washington DC'
SEARCH_LIMIT = 50
url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'offset': 100 
    }

# %%
def yelp_call(url_params, api_key):
    # your code to make the yelp call
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer ' + api_key}
    
    data = requests.get(url, headers = headers, params = url_params)
    return data

# %%
results3 = yelp_call(url_params, api_key)

# %%
results3.json()

# %%
data3_df = pd.DataFrame(results2.json()['businesses'])
data3_df

# %%
def parse_results3(results):
    # your code to parse the result to make them easier to insert into the DB
    results = results2.json()['businesses']
    parsed_data = []
    for business in results:
        if 'price' not in business:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], 'NaN',
                business['location']['zip_code'])
            parsed_data.append(biz_info)
        else:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], business['price'],
                business['location']['zip_code'])
            parsed_data.append(biz_info)
    return parsed_data

# %%
parsed_results = parse_results3(results)
parsed_results

# %%
bike_df3 = pd.DataFrame(parsed_results, columns = ('ID', 'Name', 'Is_Closed',
                                           'Review_Count', 'Rating', 'Price',
                                           'Zip_Code'))
bike_df3

# %%
bike_df3.to_csv('C:/Users/acumu/Documents/Flatiron/ds-east-042621-lectures/Phase_1/phase-1-project-yelp/bikedata3.csv', index = False)

# %%
bike_df3.shape

# %%
 csv_filepath = 'C:/Users/acumu/Documents/Flatiron/Phase_1_Project/dcbike_df.csv'

# %%
def df_safe(csv_filepath, parsed_results):
    # your code to open the csv file, concat the current data, and save the data. 
    parsed_results = pd.DataFrame(parsed_results)
    return parsed_results.to_csv(csv_filepath, mode='a', index = False, header = False)

# %% [markdown]
# - Write a script that combines the three functions above into a single process.

# %% [markdown]
# While it will take some experimentation to write the functions above, once you get them working it will be best to put them in a `.py` file and then import the functions to use in a script

# %%
from helper_funcs import *

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < 200 and cur < 1000:
    #set the offset parameter to be where you currently are in the results (replace cur with number of results)
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    df_safe(csv_filepath, parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50

# %% [markdown]
# ___

# %% [markdown]
# ## Part 3 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews. Above you ahve a model of the functions you will need to write, and how to pull them together in one script. For this part, you ahve the process below

# %% [markdown]
# - In order to pull the reveiws, you will need the business ids. So your first step will be to get all of the business ids from your businesses csv.

# %% [markdown]
# - Write a function that takes a business id and makes a call to the API for reivews

# %% [markdown]
# - Write a function to parse out the relevant information from the reviews

# %% [markdown]
# - Write a function to save the parse data into a csv file containing all of the reviews.

# %% [markdown]
# - Combine the functions above into a single script

# %%
business_ids = pd.read_csv('C:/Users/acumu/Documents/Flatiron/Phase_1_Project/dcbike_df.csv')
business_ids

# %%
business_ids['ID']

# %%
list(business_ids['ID'])

# %%
api_key = creds['key']
term = 'bike shop'
location = 'Washington DC'
SEARCH_LIMIT = 50

# %%
def yelp_call_review(api_key):
    reviews = []
    for ID in business_ids['ID']:
        url = 'https://api.yelp.com/v3/businesses/'+ID+'/reviews'
        headers = {'Authorization': 'Bearer ' + api_key}
        data = requests.get(url, headers = headers)
        reviews.append(data.text)
    return reviews

# %%
url = 'https://api.yelp.com/v3/businesses/'+business_ids['ID'][0]+'/reviews'

# %%
url

# %%
results = yelp_call_review(api_key)
results

# %%
type(results)

# %%
def parse_results_review(results):
    # your code to parse the result to make them easier to insert into the DB
    results = results.json()['reviews']
    parsed_data = []
    for review in results:
        biz_info = (review['id'], review['text'], review['rating'], review['time_created'],
                   review['user']['name'])
        parsed_data.append(biz_info)
    return parsed_data

# %%
parsed_results = parse_results_review(results)
parsed_results

# %%
csv_review_filepath = 'C:/Users/acumu/Documents/Flatiron/Phase_1_Project/dcbike_review_df.csv'

# %%
def df_safe_review(csv_review_filepath, parsed_results):
    # your code to open the csv file, concat the current data, and save the data. 
    parsed_results = pd.DataFrame(parsed_results)
    return parsed_results.to_csv(csv_review_filepath, mode='a', index = False, header = False)

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < 200 and cur < 1000:
    #set the offset parameter to be where you currently are in the results (replace cur with number of results)
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call_review(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    data = yelp_call_review(results)
    
    # use your function to insert your parsed results into the db
    df_safe_review(csv_review_filepath, parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50

# %% [markdown]
# ___

# %% [markdown]
# ## Part 4 -  Using python and pandas, write code to answer the questions below.
#
#
# - Which are the 5 most reviewed businesses in your dataset?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What percentage of your businesseshave a price label of one dollar sign? Two dollar signs? Three dollar signs? No dollar signs?
# - Return the text of the reviews for the most reviewed business.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the business with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the business with the least reviews.

# %% [markdown]
# ___

# %% [markdown]
# # Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***
